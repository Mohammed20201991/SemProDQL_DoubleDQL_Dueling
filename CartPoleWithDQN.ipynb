# %% [markdown]
# # DQN_Model with 1000 Epsoide and 4000 steps

# %%
import os
import random
import gym
import pylab
import numpy as np
from collections import deque
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam ,RMSprop
# Out:
# C:\Users\Mohammed\anaconda3\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# C:\Users\Mohammed\anaconda3\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# C:\Users\Mohammed\anaconda3\lib\site-packages\numexpr\expressions.py:21: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_forbids_neg_powint = LooseVersion(numpy.__version__) >= LooseVersion('1.12.0b1')

# %%
def DQN_Model(input_shape, action_space):
    X_input = Input(input_shape)
    X = X_input
    X = Dense(512, input_shape=input_shape, activation="relu", kernel_initializer='he_uniform')(X)
    # Hidden layer with 256 nodes
    X = Dense(256, activation="relu", kernel_initializer='he_uniform')(X) 
    # Hidden layer with 64 nodes
    X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
    # Hidden layer with 64 nodes
    X = Dense(32, activation="relu", kernel_initializer='he_uniform'  
    # Output Layer with # of actions: 2 nodes (left, right)
    X = Dense(action_space, activation="linear", kernel_initializer='he_uniform')(X
    model = Model(inputs = X_input, outputs = X)
    model.compile(loss="mean_squared_error", optimizer=RMSprop(lr=0.00025, rho=0.95, epsilon=0.01), metrics=["accuracy"])

    model.summary()
    return model

# %%
class DQNAgent:
    def __init__(self, env_name):
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.env.seed(0)  
        # by default, CartPole-v1 has max episode steps = 500
        self.env._max_episode_steps = 400
        self.state_size = self.env.observation_space.shape[0]
        self.action_size = self.env.action_space.n

        self.EPISODES = 1000
        self.memory = deque(maxlen=2000)
        
        self.gamma         = 0.95    # discount rate
        self.epsilon       = 1.0  # exploration rate
        self.epsilon_min   = 0.01
        self.epsilon_decay = 0.999
        self.batch_size    = 32
        self.train_start   = 900

        # defining model parameters
        self.ddqn = False
        self.Soft_Update = False

        self.TAU = 0.1 # target network soft update hyperparameter

        self.Save_Path = 'Models'
        self.scores, self.episodes, self.average = [], [], []
        
        if self.ddqn:
            print("----------Double DQN--------")
            self.Model_name = os.path.join(self.Save_Path,"DDQN_"+self.env_name+".h5")
        else:
            print("-------------DQN------------")
            self.Model_name = os.path.join(self.Save_Path,"DQN_"+self.env_name+".h5")
        
        # create main model
        self.model = DQN_Model(input_shape=(self.state_size,), action_space = self.action_size)
        self.target_model = DQN_Model(input_shape=(self.state_size,), action_space = self.action_size)

    # after some time interval update the target model to be same with model
    def update_target_model(self):
        if not self.Soft_Update and self.ddqn:
            self.target_model.set_weights(self.model.get_weights())
            return
        if self.Soft_Update and self.ddqn:
            q_model_theta = self.model.get_weights()
            target_model_theta = self.target_model.get_weights()
            counter = 0
            for q_weight, target_weight in zip(q_model_theta, target_model_theta):
                target_weight = target_weight * (1-self.TAU) + q_weight * self.TAU
                target_model_theta[counter] = target_weight
                counter += 1
            self.target_model.set_weights(target_model_theta)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if len(self.memory) > self.train_start:
            if self.epsilon > self.epsilon_min:
                self.epsilon *= self.epsilon_decay

    def act(self, state):
        if np.random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            return np.argmax(self.model.predict(state))

    def replay(self):
        if len(self.memory) < self.train_start:
            return
        # Randomly sample minibatch from the memory
        minibatch = random.sample(self.memory, min(self.batch_size, self.batch_size))

        state = np.zeros((self.batch_size, self.state_size))
        next_state = np.zeros((self.batch_size, self.state_size))
        action, reward, done = [], [], []

        # do this before prediction
        # for speedup, this could be done on the tensor level
        # but easier to understand using a loop
        for i in range(self.batch_size):
            state[i] = minibatch[i][0]
            action.append(minibatch[i][1])
            reward.append(minibatch[i][2])
            next_state[i] = minibatch[i][3]
            done.append(minibatch[i][4])

        # do batch prediction to save speed
        target = self.model.predict(state)
        target_next = self.model.predict(next_state)
        target_val = self.target_model.predict(next_state)

        for i in range(len(minibatch)):
            # correction on the Q value for the action used
            if done[i]:
                target[i][action[i]] = reward[i]
            else:
                if self.ddqn: # Double - DQN
                    # current Q Network selects the action
                    # a'_max = argmax_a' Q(s', a')
                    a = np.argmax(target_next[i])
                    # target Q Network evaluates the action
                    # Q_max = Q_target(s', a'_max)
                    target[i][action[i]] = reward[i] + self.gamma * (target_val[i][a])   
                else: # Standard - DQN
                    # DQN chooses the max Q value among next actions
                    # selection and evaluation of action is on the target Q Network
                    # Q_max = max_a' Q_target(s', a')
                    target[i][action[i]] = reward[i] + self.gamma * (np.amax(target_next[i]))

        # Train the Neural Network with batches
        self.model.fit(state, target, batch_size=self.batch_size, verbose=0)


    def load(self, name):
        self.model = load_model(name)

    def save(self, name):
        self.model.save(name)

    pylab.figure(figsize=(18, 9))
    def PlotModel(self, score, episode):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores) / len(self.scores))
        pylab.plot(self.episodes, self.average, 'r')
        pylab.plot(self.episodes, self.scores, 'b')
        pylab.ylabel('Score', fontsize=18)
        pylab.xlabel('Steps', fontsize=18)
        dqn = 'DQN_'
        softupdate = ''
        if self.ddqn:
            dqn = 'DDQN_'
        if self.Soft_Update:
            softupdate = '_soft'
        try:
            pylab.savefig(dqn+self.env_name+softupdate+".png")
        except OSError:
            pass

        return str(self.average[-1])[:5]
    
    def run(self):
        for e in range(self.EPISODES):
            state = self.env.reset()
            state = np.reshape(state, [1, self.state_size])
            done = False
            i = 0
            while not done:
                #self.env.render()
                action = self.act(state)
                next_state, reward, done, _ = self.env.step(action)
                next_state = np.reshape(next_state, [1, self.state_size])
                if not done or i == self.env._max_episode_steps-1:
                    reward = reward
                else:
                    reward = -100
                self.remember(state, action, reward, next_state, done)
                state = next_state
                i += 1
                if done:
                    # every step update target model
                    self.update_target_model()
                    
                    # every episode, plot the result
                    average = self.PlotModel(i, e)
                     
                    print("episode: {}/{}, score: {}, e: {:.2}, average: {}".format(e, self.EPISODES, i, self.epsilon, average))
                    if i == self.env._max_episode_steps:
#                         print("Saving trained model as cartpole-ddqn.h5")
                        print("Saving trained model as cartpole-dqn.h5")
                        self.save("cartpole-dqn.h5")
                        break
                self.replay()

    def test(self):
#         self.load("cartpole-ddqn.h5")
        self.load("cartpole-dqn.h5")

        for e in range(self.EPISODES):
            state = self.env.reset()
            state = np.reshape(state, [1, self.state_size])
            done = False
            i = 0
            while not done:
                self.env.render()
                action = np.argmax(self.model.predict(state))
                next_state, reward, done, _ = self.env.step(action)
                state = np.reshape(next_state, [1, self.state_size])
                i += 1
                if done:
                    print("episode: {}/{}, score: {}".format(e, self.EPISODES, i))
                    break

if __name__ == "__main__":
    env_name = 'CartPole-v1'
    agent = DQNAgent(env_name)
    agent.run()
    #agent.test()
# Out:
# C:\Users\Mohammed\anaconda3\lib\site-packages\gym\core.py:172: DeprecationWarning: WARN: Function `env.seed(seed)` is marked as deprecated and will be removed in the future. Please use `env.reset(seed=seed) instead.
#   deprecation(
# C:\Users\Mohammed\anaconda3\lib\site-packages\keras\optimizer_v2\rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)
# -------------DQN------------
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 4)]               0
#
#  dense (Dense)               (None, 512)               2560
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 152,482
# Trainable params: 152,482
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 4)]               0
#
#  dense_5 (Dense)             (None, 512)               2560
#
#  dense_6 (Dense)             (None, 256)               131328
#
#  dense_7 (Dense)             (None, 64)                16448
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 152,482
# Trainable params: 152,482
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0/1000, score: 44, e: 1.0, average: 44.0
# episode: 1/1000, score: 15, e: 1.0, average: 29.5
# episode: 2/1000, score: 13, e: 1.0, average: 24.0
# episode: 3/1000, score: 26, e: 1.0, average: 24.5
# episode: 4/1000, score: 16, e: 1.0, average: 22.8
# episode: 5/1000, score: 18, e: 1.0, average: 22.0
# episode: 6/1000, score: 13, e: 1.0, average: 20.71
# episode: 7/1000, score: 59, e: 1.0, average: 25.5
# episode: 8/1000, score: 16, e: 1.0, average: 24.44
# episode: 9/1000, score: 9, e: 1.0, average: 22.9
# episode: 10/1000, score: 22, e: 1.0, average: 22.81
# episode: 11/1000, score: 18, e: 1.0, average: 22.41
# episode: 12/1000, score: 20, e: 1.0, average: 22.23
# episode: 13/1000, score: 23, e: 1.0, average: 22.28
# episode: 14/1000, score: 25, e: 1.0, average: 22.46
# episode: 15/1000, score: 24, e: 1.0, average: 22.56
# episode: 16/1000, score: 19, e: 1.0, average: 22.35
# episode: 17/1000, score: 16, e: 1.0, average: 22.0
# episode: 18/1000, score: 25, e: 1.0, average: 22.15
# episode: 19/1000, score: 25, e: 1.0, average: 22.3
# episode: 20/1000, score: 40, e: 1.0, average: 23.14
# episode: 21/1000, score: 21, e: 1.0, average: 23.04
# episode: 22/1000, score: 11, e: 1.0, average: 22.52
# episode: 23/1000, score: 22, e: 1.0, average: 22.5
# episode: 24/1000, score: 38, e: 1.0, average: 23.12
# episode: 25/1000, score: 13, e: 1.0, average: 22.73
# episode: 26/1000, score: 19, e: 1.0, average: 22.59
# episode: 27/1000, score: 20, e: 1.0, average: 22.5
# episode: 28/1000, score: 11, e: 1.0, average: 22.10
# episode: 29/1000, score: 11, e: 1.0, average: 21.73
# episode: 30/1000, score: 56, e: 1.0, average: 22.83
# episode: 31/1000, score: 11, e: 1.0, average: 22.46
# episode: 32/1000, score: 26, e: 1.0, average: 22.57
# episode: 33/1000, score: 22, e: 1.0, average: 22.55
# episode: 34/1000, score: 26, e: 1.0, average: 22.65
# episode: 35/1000, score: 33, e: 1.0, average: 22.94
# episode: 36/1000, score: 30, e: 1.0, average: 23.13
# episode: 37/1000, score: 30, e: 1.0, average: 23.31
# episode: 38/1000, score: 56, e: 0.96, average: 24.15
# episode: 39/1000, score: 14, e: 0.95, average: 23.9
# episode: 40/1000, score: 33, e: 0.91, average: 24.12
# episode: 41/1000, score: 46, e: 0.87, average: 24.64
# episode: 42/1000, score: 31, e: 0.85, average: 24.79
# episode: 43/1000, score: 39, e: 0.81, average: 25.11
# episode: 44/1000, score: 14, e: 0.8, average: 24.86
# episode: 45/1000, score: 22, e: 0.79, average: 24.80
# episode: 46/1000, score: 16, e: 0.77, average: 24.61
# episode: 47/1000, score: 12, e: 0.76, average: 24.35
# episode: 48/1000, score: 28, e: 0.74, average: 24.42
# episode: 49/1000, score: 45, e: 0.71, average: 24.84
# episode: 50/1000, score: 102, e: 0.64, average: 26.35
# episode: 51/1000, score: 47, e: 0.61, average: 26.75
# episode: 52/1000, score: 75, e: 0.57, average: 27.66
# episode: 53/1000, score: 381, e: 0.39, average: 34.20
# episode: 54/1000, score: 102, e: 0.35, average: 35.43
# episode: 55/1000, score: 76, e: 0.32, average: 36.16
# episode: 56/1000, score: 104, e: 0.29, average: 37.35
# episode: 57/1000, score: 38, e: 0.28, average: 37.36
# episode: 58/1000, score: 124, e: 0.25, average: 38.83
# episode: 59/1000, score: 131, e: 0.22, average: 40.36
# episode: 60/1000, score: 102, e: 0.2, average: 41.37
# episode: 61/1000, score: 72, e: 0.18, average: 41.87
# episode: 62/1000, score: 60, e: 0.17, average: 42.15
# episode: 63/1000, score: 205, e: 0.14, average: 44.70
# episode: 64/1000, score: 103, e: 0.13, average: 45.6
# episode: 65/1000, score: 249, e: 0.099, average: 48.68
# episode: 66/1000, score: 376, e: 0.068, average: 53.56
# episode: 67/1000, score: 280, e: 0.051, average: 56.89
# episode: 68/1000, score: 315, e: 0.037, average: 60.63
# episode: 69/1000, score: 299, e: 0.028, average: 64.04
# episode: 70/1000, score: 348, e: 0.02, average: 68.04
# episode: 71/1000, score: 41, e: 0.019, average: 67.66
# episode: 72/1000, score: 9, e: 0.019, average: 66.86
# episode: 73/1000, score: 9, e: 0.018, average: 66.08
# episode: 74/1000, score: 10, e: 0.018, average: 65.33
# episode: 75/1000, score: 8, e: 0.018, average: 64.57
# episode: 76/1000, score: 10, e: 0.018, average: 63.87
# episode: 77/1000, score: 9, e: 0.018, average: 63.16
# episode: 78/1000, score: 9, e: 0.018, average: 62.48
# episode: 79/1000, score: 9, e: 0.017, average: 61.81
# episode: 80/1000, score: 10, e: 0.017, average: 61.17
# episode: 81/1000, score: 9, e: 0.017, average: 60.53
# episode: 82/1000, score: 11, e: 0.017, average: 59.93
# episode: 83/1000, score: 32, e: 0.016, average: 59.60
# episode: 84/1000, score: 145, e: 0.014, average: 60.61
# episode: 85/1000, score: 159, e: 0.012, average: 61.75
# episode: 86/1000, score: 184, e: 0.01, average: 63.16
# episode: 87/1000, score: 321, e: 0.01, average: 66.09
# episode: 88/1000, score: 134, e: 0.01, average: 66.85
# episode: 89/1000, score: 147, e: 0.01, average: 67.74
# episode: 90/1000, score: 150, e: 0.01, average: 68.64
# episode: 91/1000, score: 113, e: 0.01, average: 69.13
# episode: 92/1000, score: 168, e: 0.01, average: 70.19
# episode: 93/1000, score: 173, e: 0.01, average: 71.28
# episode: 94/1000, score: 135, e: 0.01, average: 71.95
# episode: 95/1000, score: 82, e: 0.01, average: 72.06
# episode: 96/1000, score: 233, e: 0.01, average: 73.72
# episode: 97/1000, score: 26, e: 0.01, average: 73.23
# episode: 98/1000, score: 35, e: 0.01, average: 72.84
# episode: 99/1000, score: 45, e: 0.01, average: 72.57
# episode: 100/1000, score: 54, e: 0.01, average: 72.38
# episode: 101/1000, score: 10, e: 0.01, average: 71.77
# episode: 102/1000, score: 8, e: 0.01, average: 71.15
# episode: 103/1000, score: 8, e: 0.01, average: 70.54
# episode: 104/1000, score: 10, e: 0.01, average: 69.97
# episode: 105/1000, score: 10, e: 0.01, average: 69.40
# episode: 106/1000, score: 9, e: 0.01, average: 68.84
# episode: 107/1000, score: 10, e: 0.01, average: 68.29
# episode: 108/1000, score: 9, e: 0.01, average: 67.75
# episode: 109/1000, score: 10, e: 0.01, average: 67.22
# episode: 110/1000, score: 8, e: 0.01, average: 66.69
# episode: 111/1000, score: 11, e: 0.01, average: 66.19
# episode: 112/1000, score: 393, e: 0.01, average: 69.08
# episode: 113/1000, score: 183, e: 0.01, average: 70.08
# episode: 114/1000, score: 9, e: 0.01, average: 69.55
# episode: 115/1000, score: 9, e: 0.01, average: 69.03
# episode: 116/1000, score: 9, e: 0.01, average: 68.52
# episode: 117/1000, score: 9, e: 0.01, average: 68.01
# episode: 118/1000, score: 9, e: 0.01, average: 67.52
# episode: 119/1000, score: 9, e: 0.01, average: 67.03
# episode: 120/1000, score: 11, e: 0.01, average: 66.57
# episode: 121/1000, score: 11, e: 0.01, average: 66.11
# episode: 122/1000, score: 400, e: 0.01, average: 68.82
# Saving trained model as cartpole-dqn.h5
# episode: 123/1000, score: 324, e: 0.01, average: 70.88
# episode: 124/1000, score: 400, e: 0.01, average: 73.52
# Saving trained model as cartpole-dqn.h5
# episode: 125/1000, score: 400, e: 0.01, average: 76.11
# Saving trained model as cartpole-dqn.h5
# episode: 126/1000, score: 400, e: 0.01, average: 78.66
# Saving trained model as cartpole-dqn.h5
# episode: 127/1000, score: 400, e: 0.01, average: 81.17
# Saving trained model as cartpole-dqn.h5
# episode: 128/1000, score: 210, e: 0.01, average: 82.17
# episode: 129/1000, score: 9, e: 0.01, average: 81.60
# episode: 130/1000, score: 29, e: 0.01, average: 81.20
# episode: 131/1000, score: 10, e: 0.01, average: 80.66
# episode: 132/1000, score: 90, e: 0.01, average: 80.73
# episode: 133/1000, score: 12, e: 0.01, average: 80.22
# episode: 134/1000, score: 19, e: 0.01, average: 79.77
# episode: 135/1000, score: 108, e: 0.01, average: 79.97
# episode: 136/1000, score: 143, e: 0.01, average: 80.43
# episode: 137/1000, score: 187, e: 0.01, average: 81.21
# episode: 138/1000, score: 9, e: 0.01, average: 80.69
# episode: 139/1000, score: 9, e: 0.01, average: 80.17
# episode: 140/1000, score: 10, e: 0.01, average: 79.68
# episode: 141/1000, score: 9, e: 0.01, average: 79.18
# episode: 142/1000, score: 10, e: 0.01, average: 78.69
# episode: 143/1000, score: 10, e: 0.01, average: 78.22
# episode: 144/1000, score: 10, e: 0.01, average: 77.75
# episode: 145/1000, score: 11, e: 0.01, average: 77.29
# episode: 146/1000, score: 11, e: 0.01, average: 76.84
# episode: 147/1000, score: 9, e: 0.01, average: 76.38
# episode: 148/1000, score: 26, e: 0.01, average: 76.04
# episode: 149/1000, score: 400, e: 0.01, average: 78.20
# Saving trained model as cartpole-dqn.h5
# episode: 150/1000, score: 41, e: 0.01, average: 77.96
# episode: 151/1000, score: 314, e: 0.01, average: 79.51
# episode: 152/1000, score: 277, e: 0.01, average: 80.80
# episode: 153/1000, score: 303, e: 0.01, average: 82.24
# episode: 154/1000, score: 352, e: 0.01, average: 83.98
# episode: 155/1000, score: 328, e: 0.01, average: 85.55
# episode: 156/1000, score: 337, e: 0.01, average: 87.15
# episode: 157/1000, score: 303, e: 0.01, average: 88.51
# episode: 158/1000, score: 291, e: 0.01, average: 89.79
# episode: 159/1000, score: 297, e: 0.01, average: 91.08
# episode: 160/1000, score: 231, e: 0.01, average: 91.95
# episode: 161/1000, score: 10, e: 0.01, average: 91.45
# episode: 162/1000, score: 9, e: 0.01, average: 90.94
# episode: 163/1000, score: 10, e: 0.01, average: 90.45
# episode: 164/1000, score: 159, e: 0.01, average: 90.86
# episode: 165/1000, score: 192, e: 0.01, average: 91.47
# episode: 166/1000, score: 186, e: 0.01, average: 92.04
# episode: 167/1000, score: 254, e: 0.01, average: 93.00
# episode: 168/1000, score: 252, e: 0.01, average: 93.94
# episode: 169/1000, score: 228, e: 0.01, average: 94.73
# episode: 170/1000, score: 225, e: 0.01, average: 95.49
# episode: 171/1000, score: 206, e: 0.01, average: 96.13
# episode: 172/1000, score: 293, e: 0.01, average: 97.27
# episode: 173/1000, score: 221, e: 0.01, average: 97.98
# episode: 174/1000, score: 222, e: 0.01, average: 98.69
# episode: 175/1000, score: 91, e: 0.01, average: 98.65
# episode: 176/1000, score: 111, e: 0.01, average: 98.72
# episode: 177/1000, score: 100, e: 0.01, average: 98.73
# episode: 178/1000, score: 197, e: 0.01, average: 99.27
# episode: 179/1000, score: 9, e: 0.01, average: 98.77
# episode: 180/1000, score: 10, e: 0.01, average: 98.28
# episode: 181/1000, score: 9, e: 0.01, average: 97.79
# episode: 182/1000, score: 112, e: 0.01, average: 97.87
# episode: 183/1000, score: 367, e: 0.01, average: 99.33
# episode: 184/1000, score: 9, e: 0.01, average: 98.84
# episode: 185/1000, score: 10, e: 0.01, average: 98.37
# episode: 186/1000, score: 10, e: 0.01, average: 97.89
# episode: 187/1000, score: 9, e: 0.01, average: 97.42
# episode: 188/1000, score: 9, e: 0.01, average: 96.95
# episode: 189/1000, score: 10, e: 0.01, average: 96.5
# episode: 190/1000, score: 11, e: 0.01, average: 96.05
# episode: 191/1000, score: 9, e: 0.01, average: 95.59
# episode: 192/1000, score: 9, e: 0.01, average: 95.15
# episode: 193/1000, score: 10, e: 0.01, average: 94.71
# episode: 194/1000, score: 8, e: 0.01, average: 94.26
# episode: 195/1000, score: 10, e: 0.01, average: 93.83
# episode: 196/1000, score: 10, e: 0.01, average: 93.41
# episode: 197/1000, score: 10, e: 0.01, average: 92.98
# episode: 198/1000, score: 10, e: 0.01, average: 92.57
# episode: 199/1000, score: 315, e: 0.01, average: 93.68
# episode: 200/1000, score: 280, e: 0.01, average: 94.61
# episode: 201/1000, score: 366, e: 0.01, average: 95.95
# episode: 202/1000, score: 142, e: 0.01, average: 96.18
# episode: 203/1000, score: 186, e: 0.01, average: 96.62
# episode: 204/1000, score: 265, e: 0.01, average: 97.44
# episode: 205/1000, score: 400, e: 0.01, average: 98.91
# Saving trained model as cartpole-dqn.h5
# episode: 206/1000, score: 400, e: 0.01, average: 100.3
# Saving trained model as cartpole-dqn.h5
# episode: 207/1000, score: 214, e: 0.01, average: 100.9
# episode: 208/1000, score: 180, e: 0.01, average: 101.2
# episode: 209/1000, score: 257, e: 0.01, average: 102.0
# episode: 210/1000, score: 381, e: 0.01, average: 103.3
# episode: 211/1000, score: 242, e: 0.01, average: 104.0
# episode: 212/1000, score: 152, e: 0.01, average: 104.2
# episode: 213/1000, score: 82, e: 0.01, average: 104.1
# episode: 214/1000, score: 99, e: 0.01, average: 104.1
# episode: 215/1000, score: 206, e: 0.01, average: 104.5
# episode: 216/1000, score: 195, e: 0.01, average: 104.9
# episode: 217/1000, score: 258, e: 0.01, average: 105.6
# episode: 218/1000, score: 190, e: 0.01, average: 106.0
# episode: 219/1000, score: 218, e: 0.01, average: 106.5
# episode: 220/1000, score: 233, e: 0.01, average: 107.1
# episode: 221/1000, score: 239, e: 0.01, average: 107.7
# episode: 222/1000, score: 179, e: 0.01, average: 108.0
# episode: 223/1000, score: 225, e: 0.01, average: 108.5
# episode: 224/1000, score: 190, e: 0.01, average: 108.9
# episode: 225/1000, score: 212, e: 0.01, average: 109.4
# episode: 226/1000, score: 178, e: 0.01, average: 109.7
# episode: 227/1000, score: 223, e: 0.01, average: 110.2
# episode: 228/1000, score: 171, e: 0.01, average: 110.4
# episode: 229/1000, score: 178, e: 0.01, average: 110.7
# episode: 230/1000, score: 223, e: 0.01, average: 111.2
# episode: 231/1000, score: 190, e: 0.01, average: 111.5
# episode: 232/1000, score: 9, e: 0.01, average: 111.1
# episode: 233/1000, score: 10, e: 0.01, average: 110.7
# episode: 234/1000, score: 10, e: 0.01, average: 110.2
# episode: 235/1000, score: 8, e: 0.01, average: 109.8
# episode: 236/1000, score: 10, e: 0.01, average: 109.4
# episode: 237/1000, score: 10, e: 0.01, average: 109.0
# episode: 238/1000, score: 9, e: 0.01, average: 108.6
# episode: 239/1000, score: 10, e: 0.01, average: 108.1
# episode: 240/1000, score: 11, e: 0.01, average: 107.7
# episode: 241/1000, score: 186, e: 0.01, average: 108.1
# episode: 242/1000, score: 282, e: 0.01, average: 108.8
# episode: 243/1000, score: 280, e: 0.01, average: 109.5
# episode: 244/1000, score: 10, e: 0.01, average: 109.1
# episode: 245/1000, score: 9, e: 0.01, average: 108.7
# episode: 246/1000, score: 126, e: 0.01, average: 108.7
# episode: 247/1000, score: 289, e: 0.01, average: 109.5
# episode: 248/1000, score: 135, e: 0.01, average: 109.6
# episode: 249/1000, score: 125, e: 0.01, average: 109.6
# episode: 250/1000, score: 143, e: 0.01, average: 109.8
# episode: 251/1000, score: 187, e: 0.01, average: 110.1
# episode: 252/1000, score: 180, e: 0.01, average: 110.3
# episode: 253/1000, score: 180, e: 0.01, average: 110.6
# episode: 254/1000, score: 170, e: 0.01, average: 110.9
# episode: 255/1000, score: 202, e: 0.01, average: 111.2
# episode: 256/1000, score: 30, e: 0.01, average: 110.9
# episode: 257/1000, score: 9, e: 0.01, average: 110.5
# episode: 258/1000, score: 9, e: 0.01, average: 110.1
# episode: 259/1000, score: 10, e: 0.01, average: 109.7
# episode: 260/1000, score: 8, e: 0.01, average: 109.3
# episode: 261/1000, score: 10, e: 0.01, average: 109.0
# episode: 262/1000, score: 9, e: 0.01, average: 108.6
# episode: 263/1000, score: 9, e: 0.01, average: 108.2
# episode: 264/1000, score: 9, e: 0.01, average: 107.8
# episode: 265/1000, score: 10, e: 0.01, average: 107.5
# episode: 266/1000, score: 10, e: 0.01, average: 107.1
# episode: 267/1000, score: 9, e: 0.01, average: 106.7
# episode: 268/1000, score: 11, e: 0.01, average: 106.4
# episode: 269/1000, score: 178, e: 0.01, average: 106.6
# episode: 270/1000, score: 311, e: 0.01, average: 107.4
# episode: 271/1000, score: 198, e: 0.01, average: 107.7
# episode: 272/1000, score: 305, e: 0.01, average: 108.4
# episode: 273/1000, score: 398, e: 0.01, average: 109.5
# episode: 274/1000, score: 344, e: 0.01, average: 110.3
# episode: 275/1000, score: 399, e: 0.01, average: 111.4
# episode: 276/1000, score: 374, e: 0.01, average: 112.3
# episode: 277/1000, score: 216, e: 0.01, average: 112.7
# episode: 278/1000, score: 224, e: 0.01, average: 113.1
# episode: 279/1000, score: 400, e: 0.01, average: 114.1
# Saving trained model as cartpole-dqn.h5
# episode: 280/1000, score: 117, e: 0.01, average: 114.1
# episode: 281/1000, score: 10, e: 0.01, average: 113.8
# episode: 282/1000, score: 10, e: 0.01, average: 113.4
# episode: 283/1000, score: 10, e: 0.01, average: 113.0
# episode: 284/1000, score: 10, e: 0.01, average: 112.7
# episode: 285/1000, score: 10, e: 0.01, average: 112.3
# episode: 286/1000, score: 10, e: 0.01, average: 112.0
# episode: 287/1000, score: 9, e: 0.01, average: 111.6
# episode: 288/1000, score: 9, e: 0.01, average: 111.3
# episode: 289/1000, score: 9, e: 0.01, average: 110.9
# episode: 290/1000, score: 10, e: 0.01, average: 110.6
# episode: 291/1000, score: 318, e: 0.01, average: 111.3
# episode: 292/1000, score: 400, e: 0.01, average: 112.3
# Saving trained model as cartpole-dqn.h5
# episode: 293/1000, score: 210, e: 0.01, average: 112.6
# episode: 294/1000, score: 163, e: 0.01, average: 112.8
# episode: 295/1000, score: 142, e: 0.01, average: 112.9
# episode: 296/1000, score: 113, e: 0.01, average: 112.9
# episode: 297/1000, score: 144, e: 0.01, average: 113.0
# episode: 298/1000, score: 135, e: 0.01, average: 113.0
# episode: 299/1000, score: 119, e: 0.01, average: 113.1
# episode: 300/1000, score: 143, e: 0.01, average: 113.1
# episode: 301/1000, score: 62, e: 0.01, average: 113.0
# episode: 302/1000, score: 169, e: 0.01, average: 113.2
# episode: 303/1000, score: 175, e: 0.01, average: 113.4
# episode: 304/1000, score: 136, e: 0.01, average: 113.4
# episode: 305/1000, score: 128, e: 0.01, average: 113.5
# episode: 306/1000, score: 167, e: 0.01, average: 113.7
# episode: 307/1000, score: 143, e: 0.01, average: 113.8
# episode: 308/1000, score: 162, e: 0.01, average: 113.9
# episode: 309/1000, score: 127, e: 0.01, average: 114.0
# episode: 310/1000, score: 154, e: 0.01, average: 114.1
# episode: 311/1000, score: 132, e: 0.01, average: 114.1
# episode: 312/1000, score: 9, e: 0.01, average: 113.8
# episode: 313/1000, score: 9, e: 0.01, average: 113.5
# episode: 314/1000, score: 10, e: 0.01, average: 113.1
# episode: 315/1000, score: 10, e: 0.01, average: 112.8
# episode: 316/1000, score: 12, e: 0.01, average: 112.5
# episode: 317/1000, score: 14, e: 0.01, average: 112.2
# episode: 318/1000, score: 16, e: 0.01, average: 111.9
# episode: 319/1000, score: 143, e: 0.01, average: 112.0
# episode: 320/1000, score: 179, e: 0.01, average: 112.2
# episode: 321/1000, score: 400, e: 0.01, average: 113.1
# Saving trained model as cartpole-dqn.h5
# episode: 322/1000, score: 155, e: 0.01, average: 113.2
# episode: 323/1000, score: 45, e: 0.01, average: 113.0
# episode: 324/1000, score: 231, e: 0.01, average: 113.4
# episode: 325/1000, score: 317, e: 0.01, average: 114.0
# episode: 326/1000, score: 400, e: 0.01, average: 114.9
# Saving trained model as cartpole-dqn.h5
# episode: 327/1000, score: 400, e: 0.01, average: 115.7
# Saving trained model as cartpole-dqn.h5
# episode: 328/1000, score: 400, e: 0.01, average: 116.6
# Saving trained model as cartpole-dqn.h5
# episode: 329/1000, score: 400, e: 0.01, average: 117.5
# Saving trained model as cartpole-dqn.h5
# episode: 330/1000, score: 400, e: 0.01, average: 118.3
# Saving trained model as cartpole-dqn.h5
# episode: 331/1000, score: 400, e: 0.01, average: 119.2
# Saving trained model as cartpole-dqn.h5
# episode: 332/1000, score: 400, e: 0.01, average: 120.0
# Saving trained model as cartpole-dqn.h5
# episode: 333/1000, score: 400, e: 0.01, average: 120.8
# Saving trained model as cartpole-dqn.h5
# episode: 334/1000, score: 400, e: 0.01, average: 121.7
# Saving trained model as cartpole-dqn.h5
# episode: 335/1000, score: 86, e: 0.01, average: 121.6
# episode: 336/1000, score: 197, e: 0.01, average: 121.8
# episode: 337/1000, score: 106, e: 0.01, average: 121.7
# episode: 338/1000, score: 21, e: 0.01, average: 121.4
# episode: 339/1000, score: 27, e: 0.01, average: 121.2
# episode: 340/1000, score: 61, e: 0.01, average: 121.0
# episode: 341/1000, score: 11, e: 0.01, average: 120.7
# episode: 342/1000, score: 131, e: 0.01, average: 120.7
# episode: 343/1000, score: 260, e: 0.01, average: 121.1
# episode: 344/1000, score: 286, e: 0.01, average: 121.6
# episode: 345/1000, score: 273, e: 0.01, average: 122.0
# episode: 346/1000, score: 178, e: 0.01, average: 122.2
# episode: 347/1000, score: 316, e: 0.01, average: 122.7
# episode: 348/1000, score: 216, e: 0.01, average: 123.0
# episode: 349/1000, score: 214, e: 0.01, average: 123.3
# episode: 350/1000, score: 201, e: 0.01, average: 123.5
# episode: 351/1000, score: 218, e: 0.01, average: 123.8
# episode: 352/1000, score: 337, e: 0.01, average: 124.4
# episode: 353/1000, score: 153, e: 0.01, average: 124.4
# episode: 354/1000, score: 124, e: 0.01, average: 124.4
# episode: 355/1000, score: 82, e: 0.01, average: 124.3
# episode: 356/1000, score: 81, e: 0.01, average: 124.2
# episode: 357/1000, score: 51, e: 0.01, average: 124.0
# episode: 358/1000, score: 85, e: 0.01, average: 123.9
# episode: 359/1000, score: 87, e: 0.01, average: 123.8
# episode: 360/1000, score: 215, e: 0.01, average: 124.0
# episode: 361/1000, score: 173, e: 0.01, average: 124.2
# episode: 362/1000, score: 216, e: 0.01, average: 124.4
# episode: 363/1000, score: 400, e: 0.01, average: 125.2
# Saving trained model as cartpole-dqn.h5
# episode: 364/1000, score: 400, e: 0.01, average: 125.9
# Saving trained model as cartpole-dqn.h5
# episode: 365/1000, score: 400, e: 0.01, average: 126.7
# Saving trained model as cartpole-dqn.h5
# episode: 366/1000, score: 321, e: 0.01, average: 127.2
# episode: 367/1000, score: 179, e: 0.01, average: 127.4
# episode: 368/1000, score: 199, e: 0.01, average: 127.5
# episode: 369/1000, score: 168, e: 0.01, average: 127.7
# episode: 370/1000, score: 196, e: 0.01, average: 127.8
# episode: 371/1000, score: 238, e: 0.01, average: 128.1
# episode: 372/1000, score: 180, e: 0.01, average: 128.3
# episode: 373/1000, score: 163, e: 0.01, average: 128.4
# episode: 374/1000, score: 168, e: 0.01, average: 128.5
# episode: 375/1000, score: 166, e: 0.01, average: 128.6
# episode: 376/1000, score: 192, e: 0.01, average: 128.7
# episode: 377/1000, score: 167, e: 0.01, average: 128.8
# episode: 378/1000, score: 240, e: 0.01, average: 129.1
# episode: 379/1000, score: 187, e: 0.01, average: 129.3
# episode: 380/1000, score: 192, e: 0.01, average: 129.5
# episode: 381/1000, score: 168, e: 0.01, average: 129.6
# episode: 382/1000, score: 207, e: 0.01, average: 129.8
# episode: 383/1000, score: 119, e: 0.01, average: 129.7
# episode: 384/1000, score: 123, e: 0.01, average: 129.7
# episode: 385/1000, score: 144, e: 0.01, average: 129.7
# episode: 386/1000, score: 183, e: 0.01, average: 129.9
# episode: 387/1000, score: 192, e: 0.01, average: 130.0
# episode: 388/1000, score: 400, e: 0.01, average: 130.7
# Saving trained model as cartpole-dqn.h5
# episode: 389/1000, score: 180, e: 0.01, average: 130.9
# episode: 390/1000, score: 400, e: 0.01, average: 131.6
# Saving trained model as cartpole-dqn.h5
# episode: 391/1000, score: 400, e: 0.01, average: 132.2
# Saving trained model as cartpole-dqn.h5
# episode: 392/1000, score: 400, e: 0.01, average: 132.9
# Saving trained model as cartpole-dqn.h5
# episode: 393/1000, score: 400, e: 0.01, average: 133.6
# Saving trained model as cartpole-dqn.h5
# episode: 394/1000, score: 400, e: 0.01, average: 134.3
# Saving trained model as cartpole-dqn.h5
# episode: 395/1000, score: 400, e: 0.01, average: 134.9
# Saving trained model as cartpole-dqn.h5
# episode: 396/1000, score: 400, e: 0.01, average: 135.6
# Saving trained model as cartpole-dqn.h5
# episode: 397/1000, score: 400, e: 0.01, average: 136.3
# Saving trained model as cartpole-dqn.h5
# episode: 398/1000, score: 167, e: 0.01, average: 136.3
# episode: 399/1000, score: 166, e: 0.01, average: 136.4
# episode: 400/1000, score: 48, e: 0.01, average: 136.2
# episode: 401/1000, score: 76, e: 0.01, average: 136.1
# episode: 402/1000, score: 100, e: 0.01, average: 136.0
# episode: 403/1000, score: 149, e: 0.01, average: 136.0
# episode: 404/1000, score: 62, e: 0.01, average: 135.8
# episode: 405/1000, score: 72, e: 0.01, average: 135.7
# episode: 406/1000, score: 46, e: 0.01, average: 135.4
# episode: 407/1000, score: 127, e: 0.01, average: 135.4
# episode: 408/1000, score: 385, e: 0.01, average: 136.0
# episode: 409/1000, score: 181, e: 0.01, average: 136.1
# episode: 410/1000, score: 139, e: 0.01, average: 136.1
# episode: 411/1000, score: 198, e: 0.01, average: 136.3
# episode: 412/1000, score: 198, e: 0.01, average: 136.4
# episode: 413/1000, score: 172, e: 0.01, average: 136.5
# episode: 414/1000, score: 174, e: 0.01, average: 136.6
# episode: 415/1000, score: 178, e: 0.01, average: 136.7
# episode: 416/1000, score: 155, e: 0.01, average: 136.8
# episode: 417/1000, score: 175, e: 0.01, average: 136.8
# episode: 418/1000, score: 167, e: 0.01, average: 136.9
# episode: 419/1000, score: 124, e: 0.01, average: 136.9
# episode: 420/1000, score: 166, e: 0.01, average: 137.0
# episode: 421/1000, score: 168, e: 0.01, average: 137.0
# episode: 422/1000, score: 150, e: 0.01, average: 137.1
# episode: 423/1000, score: 156, e: 0.01, average: 137.1
# episode: 424/1000, score: 180, e: 0.01, average: 137.2
# episode: 425/1000, score: 175, e: 0.01, average: 137.3
# episode: 426/1000, score: 277, e: 0.01, average: 137.6
# episode: 427/1000, score: 180, e: 0.01, average: 137.7
# episode: 428/1000, score: 251, e: 0.01, average: 138.0
# episode: 429/1000, score: 165, e: 0.01, average: 138.1
# episode: 430/1000, score: 162, e: 0.01, average: 138.1
# episode: 431/1000, score: 157, e: 0.01, average: 138.1
# episode: 432/1000, score: 168, e: 0.01, average: 138.2
# episode: 433/1000, score: 150, e: 0.01, average: 138.2
# episode: 434/1000, score: 166, e: 0.01, average: 138.3
# episode: 435/1000, score: 172, e: 0.01, average: 138.4
# episode: 436/1000, score: 185, e: 0.01, average: 138.5
# episode: 437/1000, score: 163, e: 0.01, average: 138.5
# episode: 438/1000, score: 179, e: 0.01, average: 138.6
# episode: 439/1000, score: 160, e: 0.01, average: 138.7
# episode: 440/1000, score: 198, e: 0.01, average: 138.8
# episode: 441/1000, score: 176, e: 0.01, average: 138.9
# episode: 442/1000, score: 171, e: 0.01, average: 139.0
# episode: 443/1000, score: 184, e: 0.01, average: 139.1
# episode: 444/1000, score: 170, e: 0.01, average: 139.2
# episode: 445/1000, score: 156, e: 0.01, average: 139.2
# episode: 446/1000, score: 102, e: 0.01, average: 139.1
# episode: 447/1000, score: 135, e: 0.01, average: 139.1
# episode: 448/1000, score: 141, e: 0.01, average: 139.1
# episode: 449/1000, score: 175, e: 0.01, average: 139.2
# episode: 450/1000, score: 198, e: 0.01, average: 139.3
# episode: 451/1000, score: 128, e: 0.01, average: 139.3
# episode: 452/1000, score: 176, e: 0.01, average: 139.4
# episode: 453/1000, score: 400, e: 0.01, average: 139.9
# Saving trained model as cartpole-dqn.h5
# episode: 454/1000, score: 161, e: 0.01, average: 140.0
# episode: 455/1000, score: 192, e: 0.01, average: 140.1
# episode: 456/1000, score: 166, e: 0.01, average: 140.2
# episode: 457/1000, score: 176, e: 0.01, average: 140.2
# episode: 458/1000, score: 143, e: 0.01, average: 140.2
# episode: 459/1000, score: 153, e: 0.01, average: 140.3
# episode: 460/1000, score: 155, e: 0.01, average: 140.3
# episode: 461/1000, score: 171, e: 0.01, average: 140.4
# episode: 462/1000, score: 156, e: 0.01, average: 140.4
# episode: 463/1000, score: 164, e: 0.01, average: 140.5
# episode: 464/1000, score: 164, e: 0.01, average: 140.5
# episode: 465/1000, score: 158, e: 0.01, average: 140.5
# episode: 466/1000, score: 158, e: 0.01, average: 140.6
# episode: 467/1000, score: 209, e: 0.01, average: 140.7
# episode: 468/1000, score: 248, e: 0.01, average: 141.0
# episode: 469/1000, score: 226, e: 0.01, average: 141.1
# episode: 470/1000, score: 400, e: 0.01, average: 141.7
# Saving trained model as cartpole-dqn.h5
# episode: 471/1000, score: 161, e: 0.01, average: 141.7
# episode: 472/1000, score: 137, e: 0.01, average: 141.7
# episode: 473/1000, score: 191, e: 0.01, average: 141.8
# episode: 474/1000, score: 400, e: 0.01, average: 142.4
# Saving trained model as cartpole-dqn.h5
# episode: 475/1000, score: 159, e: 0.01, average: 142.4
# episode: 476/1000, score: 196, e: 0.01, average: 142.5
# episode: 477/1000, score: 131, e: 0.01, average: 142.5
# episode: 478/1000, score: 160, e: 0.01, average: 142.5
# episode: 479/1000, score: 126, e: 0.01, average: 142.5
# episode: 480/1000, score: 127, e: 0.01, average: 142.5
# episode: 481/1000, score: 171, e: 0.01, average: 142.5
# episode: 482/1000, score: 136, e: 0.01, average: 142.5
# episode: 483/1000, score: 135, e: 0.01, average: 142.5
# episode: 484/1000, score: 137, e: 0.01, average: 142.5
# episode: 485/1000, score: 129, e: 0.01, average: 142.4
# episode: 486/1000, score: 164, e: 0.01, average: 142.5
# episode: 487/1000, score: 129, e: 0.01, average: 142.5
# episode: 488/1000, score: 151, e: 0.01, average: 142.5
# episode: 489/1000, score: 151, e: 0.01, average: 142.5
# episode: 490/1000, score: 165, e: 0.01, average: 142.5
# episode: 491/1000, score: 222, e: 0.01, average: 142.7
# episode: 492/1000, score: 134, e: 0.01, average: 142.7
# episode: 493/1000, score: 134, e: 0.01, average: 142.7
# episode: 494/1000, score: 200, e: 0.01, average: 142.8
# episode: 495/1000, score: 400, e: 0.01, average: 143.3
# Saving trained model as cartpole-dqn.h5
# episode: 496/1000, score: 127, e: 0.01, average: 143.3
# episode: 497/1000, score: 124, e: 0.01, average: 143.2
# episode: 498/1000, score: 127, e: 0.01, average: 143.2
# episode: 499/1000, score: 109, e: 0.01, average: 143.1
# episode: 500/1000, score: 189, e: 0.01, average: 143.2
# episode: 501/1000, score: 134, e: 0.01, average: 143.2
# episode: 502/1000, score: 400, e: 0.01, average: 143.7
# Saving trained model as cartpole-dqn.h5
# episode: 503/1000, score: 233, e: 0.01, average: 143.9
# episode: 504/1000, score: 400, e: 0.01, average: 144.4
# Saving trained model as cartpole-dqn.h5
# episode: 505/1000, score: 196, e: 0.01, average: 144.5
# episode: 506/1000, score: 168, e: 0.01, average: 144.5
# episode: 507/1000, score: 117, e: 0.01, average: 144.5
# episode: 508/1000, score: 72, e: 0.01, average: 144.3
# episode: 509/1000, score: 30, e: 0.01, average: 144.1
# episode: 510/1000, score: 121, e: 0.01, average: 144.1
# episode: 511/1000, score: 75, e: 0.01, average: 143.9
# episode: 512/1000, score: 123, e: 0.01, average: 143.9
# episode: 513/1000, score: 226, e: 0.01, average: 144.1
# episode: 514/1000, score: 140, e: 0.01, average: 144.1
# episode: 515/1000, score: 185, e: 0.01, average: 144.1
# episode: 516/1000, score: 188, e: 0.01, average: 144.2
# episode: 517/1000, score: 178, e: 0.01, average: 144.3
# episode: 518/1000, score: 152, e: 0.01, average: 144.3
# episode: 519/1000, score: 247, e: 0.01, average: 144.5
# episode: 520/1000, score: 229, e: 0.01, average: 144.7
# episode: 521/1000, score: 221, e: 0.01, average: 144.8
# episode: 522/1000, score: 242, e: 0.01, average: 145.0
# episode: 523/1000, score: 170, e: 0.01, average: 145.0
# episode: 524/1000, score: 172, e: 0.01, average: 145.1
# episode: 525/1000, score: 167, e: 0.01, average: 145.1
# episode: 526/1000, score: 189, e: 0.01, average: 145.2
# episode: 527/1000, score: 272, e: 0.01, average: 145.5
# episode: 528/1000, score: 219, e: 0.01, average: 145.6
# episode: 529/1000, score: 201, e: 0.01, average: 145.7
# episode: 530/1000, score: 194, e: 0.01, average: 145.8
# episode: 531/1000, score: 191, e: 0.01, average: 145.9
# episode: 532/1000, score: 206, e: 0.01, average: 146.0
# episode: 533/1000, score: 211, e: 0.01, average: 146.1
# episode: 534/1000, score: 171, e: 0.01, average: 146.2
# episode: 535/1000, score: 155, e: 0.01, average: 146.2
# episode: 536/1000, score: 145, e: 0.01, average: 146.2
# episode: 537/1000, score: 142, e: 0.01, average: 146.2
# episode: 538/1000, score: 49, e: 0.01, average: 146.0
# episode: 539/1000, score: 197, e: 0.01, average: 146.1
# episode: 540/1000, score: 162, e: 0.01, average: 146.1
# episode: 541/1000, score: 291, e: 0.01, average: 146.4
# episode: 542/1000, score: 190, e: 0.01, average: 146.4
# episode: 543/1000, score: 206, e: 0.01, average: 146.6
# episode: 544/1000, score: 93, e: 0.01, average: 146.5
# episode: 545/1000, score: 83, e: 0.01, average: 146.3
# episode: 546/1000, score: 154, e: 0.01, average: 146.4
# episode: 547/1000, score: 213, e: 0.01, average: 146.5
# episode: 548/1000, score: 182, e: 0.01, average: 146.5
# episode: 549/1000, score: 182, e: 0.01, average: 146.6
# episode: 550/1000, score: 192, e: 0.01, average: 146.7
# episode: 551/1000, score: 185, e: 0.01, average: 146.8
# episode: 552/1000, score: 245, e: 0.01, average: 146.9
# episode: 553/1000, score: 316, e: 0.01, average: 147.2
# episode: 554/1000, score: 279, e: 0.01, average: 147.5
# episode: 555/1000, score: 261, e: 0.01, average: 147.7
# episode: 556/1000, score: 284, e: 0.01, average: 147.9
# episode: 557/1000, score: 317, e: 0.01, average: 148.2
# episode: 558/1000, score: 228, e: 0.01, average: 148.4
# episode: 559/1000, score: 324, e: 0.01, average: 148.7
# episode: 560/1000, score: 400, e: 0.01, average: 149.1
# Saving trained model as cartpole-dqn.h5
# episode: 561/1000, score: 233, e: 0.01, average: 149.3
# episode: 562/1000, score: 292, e: 0.01, average: 149.5
# episode: 563/1000, score: 400, e: 0.01, average: 150.0
# Saving trained model as cartpole-dqn.h5
# episode: 564/1000, score: 252, e: 0.01, average: 150.2
# episode: 565/1000, score: 251, e: 0.01, average: 150.3
# episode: 566/1000, score: 231, e: 0.01, average: 150.5
# episode: 567/1000, score: 319, e: 0.01, average: 150.8
# episode: 568/1000, score: 246, e: 0.01, average: 150.9
# episode: 569/1000, score: 228, e: 0.01, average: 151.1
# episode: 570/1000, score: 155, e: 0.01, average: 151.1
# episode: 571/1000, score: 188, e: 0.01, average: 151.2
# episode: 572/1000, score: 139, e: 0.01, average: 151.1
# episode: 573/1000, score: 158, e: 0.01, average: 151.1
# episode: 574/1000, score: 212, e: 0.01, average: 151.2
# episode: 575/1000, score: 174, e: 0.01, average: 151.3
# episode: 576/1000, score: 142, e: 0.01, average: 151.3
# episode: 577/1000, score: 258, e: 0.01, average: 151.5
# episode: 578/1000, score: 400, e: 0.01, average: 151.9
# Saving trained model as cartpole-dqn.h5
# episode: 579/1000, score: 363, e: 0.01, average: 152.2
# episode: 580/1000, score: 333, e: 0.01, average: 152.6
# episode: 581/1000, score: 326, e: 0.01, average: 152.9
# episode: 582/1000, score: 64, e: 0.01, average: 152.7
# episode: 583/1000, score: 217, e: 0.01, average: 152.8
# episode: 584/1000, score: 164, e: 0.01, average: 152.8
# episode: 585/1000, score: 110, e: 0.01, average: 152.8
# episode: 586/1000, score: 49, e: 0.01, average: 152.6
# episode: 587/1000, score: 110, e: 0.01, average: 152.5
# episode: 588/1000, score: 30, e: 0.01, average: 152.3
# episode: 589/1000, score: 30, e: 0.01, average: 152.1
# episode: 590/1000, score: 126, e: 0.01, average: 152.1
# episode: 591/1000, score: 160, e: 0.01, average: 152.1
# episode: 592/1000, score: 167, e: 0.01, average: 152.1
# episode: 593/1000, score: 157, e: 0.01, average: 152.1
# episode: 594/1000, score: 166, e: 0.01, average: 152.1
# episode: 595/1000, score: 162, e: 0.01, average: 152.1
# episode: 596/1000, score: 292, e: 0.01, average: 152.4
# episode: 597/1000, score: 305, e: 0.01, average: 152.6
# episode: 598/1000, score: 166, e: 0.01, average: 152.6
# episode: 599/1000, score: 131, e: 0.01, average: 152.6
# episode: 600/1000, score: 249, e: 0.01, average: 152.8
# episode: 601/1000, score: 166, e: 0.01, average: 152.8
# episode: 602/1000, score: 192, e: 0.01, average: 152.9
# episode: 603/1000, score: 186, e: 0.01, average: 152.9
# episode: 604/1000, score: 139, e: 0.01, average: 152.9
# episode: 605/1000, score: 96, e: 0.01, average: 152.8
# episode: 606/1000, score: 9, e: 0.01, average: 152.6
# episode: 607/1000, score: 9, e: 0.01, average: 152.3
# episode: 608/1000, score: 9, e: 0.01, average: 152.1
# episode: 609/1000, score: 10, e: 0.01, average: 151.9
# episode: 610/1000, score: 9, e: 0.01, average: 151.6
# episode: 611/1000, score: 10, e: 0.01, average: 151.4
# episode: 612/1000, score: 9, e: 0.01, average: 151.2
# episode: 613/1000, score: 12, e: 0.01, average: 150.9
# episode: 614/1000, score: 293, e: 0.01, average: 151.2
# episode: 615/1000, score: 123, e: 0.01, average: 151.1
# episode: 616/1000, score: 125, e: 0.01, average: 151.1
# episode: 617/1000, score: 189, e: 0.01, average: 151.1
# episode: 618/1000, score: 188, e: 0.01, average: 151.2
# episode: 619/1000, score: 243, e: 0.01, average: 151.3
# episode: 620/1000, score: 167, e: 0.01, average: 151.4
# episode: 621/1000, score: 145, e: 0.01, average: 151.4
# episode: 622/1000, score: 165, e: 0.01, average: 151.4
# episode: 623/1000, score: 247, e: 0.01, average: 151.5
# episode: 624/1000, score: 192, e: 0.01, average: 151.6
# episode: 625/1000, score: 228, e: 0.01, average: 151.7
# episode: 626/1000, score: 237, e: 0.01, average: 151.9
# episode: 627/1000, score: 182, e: 0.01, average: 151.9
# episode: 628/1000, score: 284, e: 0.01, average: 152.1
# episode: 629/1000, score: 194, e: 0.01, average: 152.2
# episode: 630/1000, score: 400, e: 0.01, average: 152.6
# Saving trained model as cartpole-dqn.h5
# episode: 631/1000, score: 400, e: 0.01, average: 153.0
# Saving trained model as cartpole-dqn.h5
# episode: 632/1000, score: 153, e: 0.01, average: 153.0
# episode: 633/1000, score: 10, e: 0.01, average: 152.7
# episode: 634/1000, score: 10, e: 0.01, average: 152.5
# episode: 635/1000, score: 11, e: 0.01, average: 152.3
# episode: 636/1000, score: 189, e: 0.01, average: 152.3
# episode: 637/1000, score: 400, e: 0.01, average: 152.7
# Saving trained model as cartpole-dqn.h5
# episode: 638/1000, score: 400, e: 0.01, average: 153.1
# Saving trained model as cartpole-dqn.h5
# episode: 639/1000, score: 400, e: 0.01, average: 153.5
# Saving trained model as cartpole-dqn.h5
# episode: 640/1000, score: 400, e: 0.01, average: 153.9
# Saving trained model as cartpole-dqn.h5
# episode: 641/1000, score: 205, e: 0.01, average: 154.0
# episode: 642/1000, score: 400, e: 0.01, average: 154.4
# Saving trained model as cartpole-dqn.h5
# episode: 643/1000, score: 400, e: 0.01, average: 154.7
# Saving trained model as cartpole-dqn.h5
# episode: 644/1000, score: 400, e: 0.01, average: 155.1
# Saving trained model as cartpole-dqn.h5
# episode: 645/1000, score: 400, e: 0.01, average: 155.5
# Saving trained model as cartpole-dqn.h5
# episode: 646/1000, score: 400, e: 0.01, average: 155.9
# Saving trained model as cartpole-dqn.h5
# episode: 647/1000, score: 400, e: 0.01, average: 156.3
# Saving trained model as cartpole-dqn.h5
# episode: 648/1000, score: 360, e: 0.01, average: 156.6
# episode: 649/1000, score: 383, e: 0.01, average: 156.9
# episode: 650/1000, score: 188, e: 0.01, average: 157.0
# episode: 651/1000, score: 86, e: 0.01, average: 156.9
# episode: 652/1000, score: 9, e: 0.01, average: 156.6
# episode: 653/1000, score: 10, e: 0.01, average: 156.4
# episode: 654/1000, score: 9, e: 0.01, average: 156.2
# episode: 655/1000, score: 9, e: 0.01, average: 156.0
# episode: 656/1000, score: 9, e: 0.01, average: 155.7
# episode: 657/1000, score: 9, e: 0.01, average: 155.5
# episode: 658/1000, score: 9, e: 0.01, average: 155.3
# episode: 659/1000, score: 9, e: 0.01, average: 155.1
# episode: 660/1000, score: 9, e: 0.01, average: 154.8
# episode: 661/1000, score: 10, e: 0.01, average: 154.6
# episode: 662/1000, score: 9, e: 0.01, average: 154.4
# episode: 663/1000, score: 9, e: 0.01, average: 154.2
# episode: 664/1000, score: 10, e: 0.01, average: 154.0
# episode: 665/1000, score: 10, e: 0.01, average: 153.7
# episode: 666/1000, score: 9, e: 0.01, average: 153.5
# episode: 667/1000, score: 9, e: 0.01, average: 153.3
# episode: 668/1000, score: 9, e: 0.01, average: 153.1
# episode: 669/1000, score: 10, e: 0.01, average: 152.9
# episode: 670/1000, score: 10, e: 0.01, average: 152.7
# episode: 671/1000, score: 25, e: 0.01, average: 152.5
# episode: 672/1000, score: 42, e: 0.01, average: 152.3
# episode: 673/1000, score: 166, e: 0.01, average: 152.3
# episode: 674/1000, score: 249, e: 0.01, average: 152.5
# episode: 675/1000, score: 156, e: 0.01, average: 152.5
# episode: 676/1000, score: 160, e: 0.01, average: 152.5
# episode: 677/1000, score: 165, e: 0.01, average: 152.5
# episode: 678/1000, score: 400, e: 0.01, average: 152.9
# Saving trained model as cartpole-dqn.h5
# episode: 679/1000, score: 400, e: 0.01, average: 153.2
# Saving trained model as cartpole-dqn.h5
# episode: 680/1000, score: 400, e: 0.01, average: 153.6
# Saving trained model as cartpole-dqn.h5
# episode: 681/1000, score: 363, e: 0.01, average: 153.9
# episode: 682/1000, score: 10, e: 0.01, average: 153.7
# episode: 683/1000, score: 11, e: 0.01, average: 153.5
# episode: 684/1000, score: 9, e: 0.01, average: 153.3
# episode: 685/1000, score: 11, e: 0.01, average: 153.1
# episode: 686/1000, score: 100, e: 0.01, average: 153.0
# episode: 687/1000, score: 9, e: 0.01, average: 152.8
# episode: 688/1000, score: 10, e: 0.01, average: 152.6
# episode: 689/1000, score: 9, e: 0.01, average: 152.4
# episode: 690/1000, score: 10, e: 0.01, average: 152.2
# episode: 691/1000, score: 10, e: 0.01, average: 152.0
# episode: 692/1000, score: 10, e: 0.01, average: 151.8
# episode: 693/1000, score: 400, e: 0.01, average: 152.1
# Saving trained model as cartpole-dqn.h5
# episode: 694/1000, score: 157, e: 0.01, average: 152.1
# episode: 695/1000, score: 155, e: 0.01, average: 152.1
# episode: 696/1000, score: 196, e: 0.01, average: 152.2
# episode: 697/1000, score: 400, e: 0.01, average: 152.5
# Saving trained model as cartpole-dqn.h5
# episode: 698/1000, score: 190, e: 0.01, average: 152.6
# episode: 699/1000, score: 171, e: 0.01, average: 152.6
# episode: 700/1000, score: 161, e: 0.01, average: 152.6
# episode: 701/1000, score: 178, e: 0.01, average: 152.7
# episode: 702/1000, score: 299, e: 0.01, average: 152.9
# episode: 703/1000, score: 180, e: 0.01, average: 152.9
# episode: 704/1000, score: 258, e: 0.01, average: 153.1
# episode: 705/1000, score: 193, e: 0.01, average: 153.1
# episode: 706/1000, score: 313, e: 0.01, average: 153.3
# episode: 707/1000, score: 257, e: 0.01, average: 153.5
# episode: 708/1000, score: 191, e: 0.01, average: 153.5
# episode: 709/1000, score: 148, e: 0.01, average: 153.5
# episode: 710/1000, score: 331, e: 0.01, average: 153.8
# episode: 711/1000, score: 120, e: 0.01, average: 153.7
# episode: 712/1000, score: 192, e: 0.01, average: 153.8
# episode: 713/1000, score: 267, e: 0.01, average: 154.0
# episode: 714/1000, score: 299, e: 0.01, average: 154.2
# episode: 715/1000, score: 204, e: 0.01, average: 154.2
# episode: 716/1000, score: 182, e: 0.01, average: 154.3
# episode: 717/1000, score: 242, e: 0.01, average: 154.4
# episode: 718/1000, score: 153, e: 0.01, average: 154.4
# episode: 719/1000, score: 155, e: 0.01, average: 154.4
# episode: 720/1000, score: 247, e: 0.01, average: 154.5
# episode: 721/1000, score: 250, e: 0.01, average: 154.6
# episode: 722/1000, score: 58, e: 0.01, average: 154.5
# episode: 723/1000, score: 143, e: 0.01, average: 154.5
# episode: 724/1000, score: 143, e: 0.01, average: 154.5
# episode: 725/1000, score: 268, e: 0.01, average: 154.6
# episode: 726/1000, score: 188, e: 0.01, average: 154.7
# episode: 727/1000, score: 188, e: 0.01, average: 154.7
# episode: 728/1000, score: 400, e: 0.01, average: 155.1
# Saving trained model as cartpole-dqn.h5
# episode: 729/1000, score: 146, e: 0.01, average: 155.1
# episode: 730/1000, score: 355, e: 0.01, average: 155.3
# episode: 731/1000, score: 297, e: 0.01, average: 155.5
# episode: 732/1000, score: 294, e: 0.01, average: 155.7
# episode: 733/1000, score: 291, e: 0.01, average: 155.9
# episode: 734/1000, score: 133, e: 0.01, average: 155.9
# episode: 735/1000, score: 152, e: 0.01, average: 155.9
# episode: 736/1000, score: 343, e: 0.01, average: 156.1
# episode: 737/1000, score: 204, e: 0.01, average: 156.2
# episode: 738/1000, score: 311, e: 0.01, average: 156.4
# episode: 739/1000, score: 400, e: 0.01, average: 156.7
# Saving trained model as cartpole-dqn.h5
# episode: 740/1000, score: 316, e: 0.01, average: 156.9
# episode: 741/1000, score: 400, e: 0.01, average: 157.3
# Saving trained model as cartpole-dqn.h5
# episode: 742/1000, score: 230, e: 0.01, average: 157.4
# episode: 743/1000, score: 314, e: 0.01, average: 157.6
# episode: 744/1000, score: 116, e: 0.01, average: 157.5
# episode: 745/1000, score: 124, e: 0.01, average: 157.5
# episode: 746/1000, score: 103, e: 0.01, average: 157.4
# episode: 747/1000, score: 317, e: 0.01, average: 157.6
# episode: 748/1000, score: 180, e: 0.01, average: 157.6
# episode: 749/1000, score: 400, e: 0.01, average: 158.0
# Saving trained model as cartpole-dqn.h5
# episode: 750/1000, score: 155, e: 0.01, average: 158.0
# episode: 751/1000, score: 301, e: 0.01, average: 158.1
# episode: 752/1000, score: 355, e: 0.01, average: 158.4
# episode: 753/1000, score: 289, e: 0.01, average: 158.6
# episode: 754/1000, score: 131, e: 0.01, average: 158.5
# episode: 755/1000, score: 331, e: 0.01, average: 158.8
# episode: 756/1000, score: 288, e: 0.01, average: 158.9
# episode: 757/1000, score: 321, e: 0.01, average: 159.2
# episode: 758/1000, score: 400, e: 0.01, average: 159.5
# Saving trained model as cartpole-dqn.h5
# episode: 759/1000, score: 400, e: 0.01, average: 159.8
# Saving trained model as cartpole-dqn.h5
# episode: 760/1000, score: 340, e: 0.01, average: 160.0
# episode: 761/1000, score: 362, e: 0.01, average: 160.3
# episode: 762/1000, score: 349, e: 0.01, average: 160.5
# episode: 763/1000, score: 400, e: 0.01, average: 160.8
# Saving trained model as cartpole-dqn.h5
# episode: 764/1000, score: 400, e: 0.01, average: 161.2
# Saving trained model as cartpole-dqn.h5
# episode: 765/1000, score: 163, e: 0.01, average: 161.2
# episode: 766/1000, score: 298, e: 0.01, average: 161.3
# episode: 767/1000, score: 400, e: 0.01, average: 161.7
# Saving trained model as cartpole-dqn.h5
# episode: 768/1000, score: 400, e: 0.01, average: 162.0
# Saving trained model as cartpole-dqn.h5
# episode: 769/1000, score: 369, e: 0.01, average: 162.2
# episode: 770/1000, score: 144, e: 0.01, average: 162.2
# episode: 771/1000, score: 153, e: 0.01, average: 162.2
# episode: 772/1000, score: 271, e: 0.01, average: 162.3
# episode: 773/1000, score: 129, e: 0.01, average: 162.3
# episode: 774/1000, score: 104, e: 0.01, average: 162.2
# episode: 775/1000, score: 338, e: 0.01, average: 162.4
# episode: 776/1000, score: 140, e: 0.01, average: 162.4
# episode: 777/1000, score: 187, e: 0.01, average: 162.4
# episode: 778/1000, score: 137, e: 0.01, average: 162.4
# episode: 779/1000, score: 285, e: 0.01, average: 162.6
# episode: 780/1000, score: 142, e: 0.01, average: 162.5
# episode: 781/1000, score: 330, e: 0.01, average: 162.8
# episode: 782/1000, score: 166, e: 0.01, average: 162.8
# episode: 783/1000, score: 400, e: 0.01, average: 163.1
# Saving trained model as cartpole-dqn.h5
# episode: 784/1000, score: 400, e: 0.01, average: 163.4
# Saving trained model as cartpole-dqn.h5
# episode: 785/1000, score: 192, e: 0.01, average: 163.4
# episode: 786/1000, score: 247, e: 0.01, average: 163.5
# episode: 787/1000, score: 319, e: 0.01, average: 163.7
# episode: 788/1000, score: 160, e: 0.01, average: 163.7
# episode: 789/1000, score: 256, e: 0.01, average: 163.8
# episode: 790/1000, score: 192, e: 0.01, average: 163.9
# episode: 791/1000, score: 219, e: 0.01, average: 163.9
# episode: 792/1000, score: 204, e: 0.01, average: 164.0
# episode: 793/1000, score: 204, e: 0.01, average: 164.0
# episode: 794/1000, score: 199, e: 0.01, average: 164.1
# episode: 795/1000, score: 250, e: 0.01, average: 164.2
# episode: 796/1000, score: 222, e: 0.01, average: 164.2
# episode: 797/1000, score: 237, e: 0.01, average: 164.3
# episode: 798/1000, score: 201, e: 0.01, average: 164.4
# episode: 799/1000, score: 277, e: 0.01, average: 164.5
# episode: 800/1000, score: 270, e: 0.01, average: 164.7
# episode: 801/1000, score: 352, e: 0.01, average: 164.9
# episode: 802/1000, score: 400, e: 0.01, average: 165.2
# Saving trained model as cartpole-dqn.h5
# episode: 803/1000, score: 400, e: 0.01, average: 165.5
# Saving trained model as cartpole-dqn.h5
# episode: 804/1000, score: 400, e: 0.01, average: 165.8
# Saving trained model as cartpole-dqn.h5
# episode: 805/1000, score: 400, e: 0.01, average: 166.1
# Saving trained model as cartpole-dqn.h5
# episode: 806/1000, score: 218, e: 0.01, average: 166.1
# episode: 807/1000, score: 315, e: 0.01, average: 166.3
# episode: 808/1000, score: 198, e: 0.01, average: 166.3
# episode: 809/1000, score: 400, e: 0.01, average: 166.6
# Saving trained model as cartpole-dqn.h5
# episode: 810/1000, score: 124, e: 0.01, average: 166.6
# episode: 811/1000, score: 157, e: 0.01, average: 166.6
# episode: 812/1000, score: 353, e: 0.01, average: 166.8
# episode: 813/1000, score: 160, e: 0.01, average: 166.8
# episode: 814/1000, score: 146, e: 0.01, average: 166.8
# episode: 815/1000, score: 331, e: 0.01, average: 167.0
# episode: 816/1000, score: 211, e: 0.01, average: 167.0
# episode: 817/1000, score: 145, e: 0.01, average: 167.0
# episode: 818/1000, score: 160, e: 0.01, average: 167.0
# episode: 819/1000, score: 172, e: 0.01, average: 167.0
# episode: 820/1000, score: 147, e: 0.01, average: 167.0
# episode: 821/1000, score: 204, e: 0.01, average: 167.0
# episode: 822/1000, score: 172, e: 0.01, average: 167.0
# episode: 823/1000, score: 303, e: 0.01, average: 167.2
# episode: 824/1000, score: 209, e: 0.01, average: 167.2
# episode: 825/1000, score: 315, e: 0.01, average: 167.4
# episode: 826/1000, score: 224, e: 0.01, average: 167.5
# episode: 827/1000, score: 174, e: 0.01, average: 167.5
# episode: 828/1000, score: 214, e: 0.01, average: 167.5
# episode: 829/1000, score: 211, e: 0.01, average: 167.6
# episode: 830/1000, score: 212, e: 0.01, average: 167.7
# episode: 831/1000, score: 217, e: 0.01, average: 167.7
# episode: 832/1000, score: 193, e: 0.01, average: 167.7
# episode: 833/1000, score: 239, e: 0.01, average: 167.8
# episode: 834/1000, score: 237, e: 0.01, average: 167.9
# episode: 835/1000, score: 234, e: 0.01, average: 168.0
# episode: 836/1000, score: 212, e: 0.01, average: 168.0
# episode: 837/1000, score: 165, e: 0.01, average: 168.0
# episode: 838/1000, score: 229, e: 0.01, average: 168.1
# episode: 839/1000, score: 235, e: 0.01, average: 168.2
# episode: 840/1000, score: 185, e: 0.01, average: 168.2
# episode: 841/1000, score: 400, e: 0.01, average: 168.5
# Saving trained model as cartpole-dqn.h5
# episode: 842/1000, score: 236, e: 0.01, average: 168.6
# episode: 843/1000, score: 256, e: 0.01, average: 168.7
# episode: 844/1000, score: 339, e: 0.01, average: 168.9
# episode: 845/1000, score: 364, e: 0.01, average: 169.1
# episode: 846/1000, score: 400, e: 0.01, average: 169.4
# Saving trained model as cartpole-dqn.h5
# episode: 847/1000, score: 340, e: 0.01, average: 169.6
# episode: 848/1000, score: 400, e: 0.01, average: 169.8
# Saving trained model as cartpole-dqn.h5
# episode: 849/1000, score: 58, e: 0.01, average: 169.7
# episode: 850/1000, score: 76, e: 0.01, average: 169.6
# episode: 851/1000, score: 65, e: 0.01, average: 169.5
# episode: 852/1000, score: 400, e: 0.01, average: 169.7
# Saving trained model as cartpole-dqn.h5
# episode: 853/1000, score: 368, e: 0.01, average: 170.0
# episode: 854/1000, score: 400, e: 0.01, average: 170.3
# Saving trained model as cartpole-dqn.h5
# episode: 855/1000, score: 134, e: 0.01, average: 170.2
# episode: 856/1000, score: 109, e: 0.01, average: 170.1
# episode: 857/1000, score: 289, e: 0.01, average: 170.3
# episode: 858/1000, score: 113, e: 0.01, average: 170.2
# episode: 859/1000, score: 71, e: 0.01, average: 170.1
# episode: 860/1000, score: 110, e: 0.01, average: 170.0
# episode: 861/1000, score: 84, e: 0.01, average: 169.9
# episode: 862/1000, score: 89, e: 0.01, average: 169.8
# episode: 863/1000, score: 104, e: 0.01, average: 169.8
# episode: 864/1000, score: 92, e: 0.01, average: 169.7
# episode: 865/1000, score: 145, e: 0.01, average: 169.6
# episode: 866/1000, score: 170, e: 0.01, average: 169.6
# episode: 867/1000, score: 234, e: 0.01, average: 169.7
# episode: 868/1000, score: 195, e: 0.01, average: 169.7
# episode: 869/1000, score: 241, e: 0.01, average: 169.8
# episode: 870/1000, score: 152, e: 0.01, average: 169.8
# episode: 871/1000, score: 145, e: 0.01, average: 169.8
# episode: 872/1000, score: 123, e: 0.01, average: 169.7
# episode: 873/1000, score: 200, e: 0.01, average: 169.8
# episode: 874/1000, score: 131, e: 0.01, average: 169.7
# episode: 875/1000, score: 135, e: 0.01, average: 169.7
# episode: 876/1000, score: 119, e: 0.01, average: 169.6
# episode: 877/1000, score: 122, e: 0.01, average: 169.6
# episode: 878/1000, score: 149, e: 0.01, average: 169.5
# episode: 879/1000, score: 141, e: 0.01, average: 169.5
# episode: 880/1000, score: 122, e: 0.01, average: 169.4
# episode: 881/1000, score: 131, e: 0.01, average: 169.4
# episode: 882/1000, score: 119, e: 0.01, average: 169.3
# episode: 883/1000, score: 126, e: 0.01, average: 169.3
# episode: 884/1000, score: 136, e: 0.01, average: 169.3
# episode: 885/1000, score: 140, e: 0.01, average: 169.2
# episode: 886/1000, score: 138, e: 0.01, average: 169.2
# episode: 887/1000, score: 168, e: 0.01, average: 169.2
# episode: 888/1000, score: 141, e: 0.01, average: 169.2
# episode: 889/1000, score: 219, e: 0.01, average: 169.2
# episode: 890/1000, score: 136, e: 0.01, average: 169.2
# episode: 891/1000, score: 154, e: 0.01, average: 169.2
# episode: 892/1000, score: 152, e: 0.01, average: 169.1
# episode: 893/1000, score: 145, e: 0.01, average: 169.1
# episode: 894/1000, score: 137, e: 0.01, average: 169.1
# episode: 895/1000, score: 188, e: 0.01, average: 169.1
# episode: 896/1000, score: 156, e: 0.01, average: 169.1
# episode: 897/1000, score: 148, e: 0.01, average: 169.1
# episode: 898/1000, score: 177, e: 0.01, average: 169.1
# episode: 899/1000, score: 140, e: 0.01, average: 169.0
# episode: 900/1000, score: 126, e: 0.01, average: 169.0
# episode: 901/1000, score: 153, e: 0.01, average: 169.0
# episode: 902/1000, score: 123, e: 0.01, average: 168.9
# episode: 903/1000, score: 206, e: 0.01, average: 169.0
# episode: 904/1000, score: 138, e: 0.01, average: 168.9
# episode: 905/1000, score: 133, e: 0.01, average: 168.9
# episode: 906/1000, score: 133, e: 0.01, average: 168.8
# episode: 907/1000, score: 136, e: 0.01, average: 168.8
# episode: 908/1000, score: 132, e: 0.01, average: 168.8
# episode: 909/1000, score: 121, e: 0.01, average: 168.7
# episode: 910/1000, score: 158, e: 0.01, average: 168.7
# episode: 911/1000, score: 127, e: 0.01, average: 168.7
# episode: 912/1000, score: 121, e: 0.01, average: 168.6
# episode: 913/1000, score: 156, e: 0.01, average: 168.6
# episode: 914/1000, score: 148, e: 0.01, average: 168.6
# episode: 915/1000, score: 154, e: 0.01, average: 168.6
# episode: 916/1000, score: 127, e: 0.01, average: 168.5
# episode: 917/1000, score: 126, e: 0.01, average: 168.5
# episode: 918/1000, score: 121, e: 0.01, average: 168.4
# episode: 919/1000, score: 118, e: 0.01, average: 168.4
# episode: 920/1000, score: 125, e: 0.01, average: 168.3
# episode: 921/1000, score: 150, e: 0.01, average: 168.3
# episode: 922/1000, score: 148, e: 0.01, average: 168.3
# episode: 923/1000, score: 206, e: 0.01, average: 168.3
# episode: 924/1000, score: 125, e: 0.01, average: 168.3
# episode: 925/1000, score: 147, e: 0.01, average: 168.2
# episode: 926/1000, score: 130, e: 0.01, average: 168.2
# episode: 927/1000, score: 128, e: 0.01, average: 168.2
# episode: 928/1000, score: 146, e: 0.01, average: 168.1
# episode: 929/1000, score: 137, e: 0.01, average: 168.1
# episode: 930/1000, score: 142, e: 0.01, average: 168.1
# episode: 931/1000, score: 133, e: 0.01, average: 168.0
# episode: 932/1000, score: 157, e: 0.01, average: 168.0
# episode: 933/1000, score: 128, e: 0.01, average: 168.0
# episode: 934/1000, score: 126, e: 0.01, average: 167.9
# episode: 935/1000, score: 127, e: 0.01, average: 167.9
# episode: 936/1000, score: 131, e: 0.01, average: 167.8
# episode: 937/1000, score: 209, e: 0.01, average: 167.9
# episode: 938/1000, score: 128, e: 0.01, average: 167.8
# episode: 939/1000, score: 170, e: 0.01, average: 167.9
# episode: 940/1000, score: 145, e: 0.01, average: 167.8
# episode: 941/1000, score: 190, e: 0.01, average: 167.9
# episode: 942/1000, score: 200, e: 0.01, average: 167.9
# episode: 943/1000, score: 164, e: 0.01, average: 167.9
# episode: 944/1000, score: 119, e: 0.01, average: 167.8
# episode: 945/1000, score: 112, e: 0.01, average: 167.8
# episode: 946/1000, score: 105, e: 0.01, average: 167.7
# episode: 947/1000, score: 15, e: 0.01, average: 167.5
# episode: 948/1000, score: 11, e: 0.01, average: 167.4
# episode: 949/1000, score: 15, e: 0.01, average: 167.2
# episode: 950/1000, score: 16, e: 0.01, average: 167.1
# episode: 951/1000, score: 110, e: 0.01, average: 167.0
# episode: 952/1000, score: 147, e: 0.01, average: 167.0
# episode: 953/1000, score: 124, e: 0.01, average: 166.9
# episode: 954/1000, score: 170, e: 0.01, average: 166.9
# episode: 955/1000, score: 179, e: 0.01, average: 166.9
# episode: 956/1000, score: 210, e: 0.01, average: 167.0
# episode: 957/1000, score: 156, e: 0.01, average: 167.0
# episode: 958/1000, score: 179, e: 0.01, average: 167.0
# episode: 959/1000, score: 271, e: 0.01, average: 167.1
# episode: 960/1000, score: 321, e: 0.01, average: 167.3
# episode: 961/1000, score: 164, e: 0.01, average: 167.3
# episode: 962/1000, score: 173, e: 0.01, average: 167.3
# episode: 963/1000, score: 262, e: 0.01, average: 167.4
# episode: 964/1000, score: 231, e: 0.01, average: 167.4
# episode: 965/1000, score: 181, e: 0.01, average: 167.4
# episode: 966/1000, score: 198, e: 0.01, average: 167.5
# episode: 967/1000, score: 170, e: 0.01, average: 167.5
# episode: 968/1000, score: 151, e: 0.01, average: 167.5
# episode: 969/1000, score: 143, e: 0.01, average: 167.4
# episode: 970/1000, score: 185, e: 0.01, average: 167.5
# episode: 971/1000, score: 178, e: 0.01, average: 167.5
# episode: 972/1000, score: 145, e: 0.01, average: 167.4
# episode: 973/1000, score: 145, e: 0.01, average: 167.4
# episode: 974/1000, score: 144, e: 0.01, average: 167.4
# episode: 975/1000, score: 201, e: 0.01, average: 167.4
# episode: 976/1000, score: 125, e: 0.01, average: 167.4
# episode: 977/1000, score: 118, e: 0.01, average: 167.3
# episode: 978/1000, score: 10, e: 0.01, average: 167.2
# episode: 979/1000, score: 11, e: 0.01, average: 167.0
# episode: 980/1000, score: 10, e: 0.01, average: 166.9
# episode: 981/1000, score: 143, e: 0.01, average: 166.8
# episode: 982/1000, score: 123, e: 0.01, average: 166.8
# episode: 983/1000, score: 161, e: 0.01, average: 166.8
# episode: 984/1000, score: 130, e: 0.01, average: 166.7
# episode: 985/1000, score: 261, e: 0.01, average: 166.8
# episode: 986/1000, score: 151, e: 0.01, average: 166.8
# episode: 987/1000, score: 147, e: 0.01, average: 166.8
# episode: 988/1000, score: 145, e: 0.01, average: 166.8
# episode: 989/1000, score: 138, e: 0.01, average: 166.7
# episode: 990/1000, score: 162, e: 0.01, average: 166.7
# episode: 991/1000, score: 156, e: 0.01, average: 166.7
# episode: 992/1000, score: 135, e: 0.01, average: 166.7
# episode: 993/1000, score: 139, e: 0.01, average: 166.7
# episode: 994/1000, score: 168, e: 0.01, average: 166.7
# episode: 995/1000, score: 128, e: 0.01, average: 166.6
# episode: 996/1000, score: 225, e: 0.01, average: 166.7
# episode: 997/1000, score: 135, e: 0.01, average: 166.7
# episode: 998/1000, score: 137, e: 0.01, average: 166.6
# episode: 999/1000, score: 183, e: 0.01, average: 166.6

# %% [markdown]
# # Testing part
# we need to be awear with dir

# %%
if __name__ == "__main__":
    env_name = 'CartPole-v1'
    agent = DQNAgent(env_name)
    agent.test()
