# %% [markdown]
# DQN With other test less epsoied

# %%
import os
import random
import gym
import pylab
import numpy as np
from collections import deque
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam ,RMSprop
# Out:
# C:\Users\Mohammed\anaconda3\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(module.__version__) < minver:
# C:\Users\Mohammed\anaconda3\lib\site-packages\setuptools\_distutils\version.py:351: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   other = LooseVersion(other)
# C:\Users\Mohammed\anaconda3\lib\site-packages\numexpr\expressions.py:21: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   _np_version_forbids_neg_powint = LooseVersion(numpy.__version__) >= LooseVersion('1.12.0b1')

# %%
def Model(input_shape, action_space):
    X_input = Input(input_shape)
    X = X_input
    X = Dense(512, input_shape=input_shape, activation="relu", kernel_initializer='he_uniform')(X)
    X = Dense(256, activation="relu", kernel_initializer='he_uniform')(X)
    # Hidden layer with 64 nodes
    X = Dense(64, activation="relu", kernel_initializer='he_uniform')(X)
    # Hidden layer with 64 nodes
    X = Dense(32, activation="relu", kernel_initializer='he_uniform')(X) 
    # Output Layer with # of actions: 2 nodes (left, right)
    X = Dense(action_space, activation="linear", kernel_initializer='he_uniform')(X)
    model = Model(inputs = X_input, outputs = X)
    model.compile(loss="mean_squared_error", optimizer=RMSprop(lr=0.00025, rho=0.95, epsilon=0.01), metrics=["accuracy"])
    model.summary()
    return model

# %%
class DQNAgent:
    def __init__(self, env_name):
        self.env_name = env_name       
        self.env = gym.make(env_name)
        self.env.seed(0)  
        self.env._max_episode_steps = 400 #4000
        self.state_size = self.env.observation_space.shape[0]
        self.action_size = self.env.action_space.n

        self.EPISODES = 100 #1000
        self.memory = deque(maxlen=2000)
        
        self.gamma         = 0.95    # discount rate
        self.epsilon       = 1.0  # exploration rate
        self.epsilon_min   = 0.01
        self.epsilon_decay = 0.999
        self.batch_size    = 32
        self.train_start   = 900
        # we need to test DQN so we set Double to false 
        self.ddqn = False
        self.Soft_Update = False

        self.TAU = 0.1 # target network soft update hyperparameter

        self.Save_Path = 'Models'
        self.scores, self.episodes, self.average = [], [], []
        
        if self.ddqn:
            print("----------Double DQN--------")
            self.Model_name = os.path.join(self.Save_Path,"DDQN_"+self.env_name+".h5")
        else:
            print("-------------DQN------------")
            self.Model_name = os.path.join(self.Save_Path,"DQN_"+self.env_name+".h5")
        
        # create main model
        self.model = Model(input_shape=(self.state_size,), action_space = self.action_size)
        self.target_model = Model(input_shape=(self.state_size,), action_space = self.action_size)

    # after some time interval update the target model to be same with model
    def update_target_model(self):
        if not self.Soft_Update and self.ddqn:
            self.target_model.set_weights(self.model.get_weights())
            return
        if self.Soft_Update and self.ddqn:
            q_model_theta = self.model.get_weights()
            target_model_theta = self.target_model.get_weights()
            counter = 0
            for q_weight, target_weight in zip(q_model_theta, target_model_theta):
                target_weight = target_weight * (1-self.TAU) + q_weight * self.TAU
                target_model_theta[counter] = target_weight
                counter += 1
            self.target_model.set_weights(target_model_theta)

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if len(self.memory) > self.train_start:
            if self.epsilon > self.epsilon_min:
                self.epsilon *= self.epsilon_decay

    def act(self, state):
        if np.random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            return np.argmax(self.model.predict(state))

    def replay(self):
        if len(self.memory) < self.train_start:
            return
        # Randomly sample minibatch from the memory
        minibatch = random.sample(self.memory, min(self.batch_size, self.batch_size))

        state = np.zeros((self.batch_size, self.state_size))
        next_state = np.zeros((self.batch_size, self.state_size))
        action, reward, done = [], [], []

        # do this before prediction
        # for speedup, this could be done on the tensor level
        # but easier to understand using a loop
        for i in range(self.batch_size):
            state[i] = minibatch[i][0]
            action.append(minibatch[i][1])
            reward.append(minibatch[i][2])
            next_state[i] = minibatch[i][3]
            done.append(minibatch[i][4])

        # do batch prediction to save speed
        target = self.model.predict(state)
        target_next = self.model.predict(next_state)
        target_val = self.target_model.predict(next_state)

        for i in range(len(minibatch)):
            # correction on the Q value for the action used
            if done[i]:
                target[i][action[i]] = reward[i]
            else:
                if self.ddqn: # Double - DQN
                    # current Q Network selects the action
                    # a'_max = argmax_a' Q(s', a')
                    a = np.argmax(target_next[i])
                    # target Q Network evaluates the action
                    # Q_max = Q_target(s', a'_max)
                    target[i][action[i]] = reward[i] + self.gamma * (target_val[i][a])   
                else: # Standard - DQN
                    # DQN chooses the max Q value among next actions
                    # selection and evaluation of action is on the target Q Network
                    # Q_max = max_a' Q_target(s', a')
                    target[i][action[i]] = reward[i] + self.gamma * (np.amax(target_next[i]))

        # Train the Neural Network with batches
        self.model.fit(state, target, batch_size=self.batch_size, verbose=0)


    def load(self, name):
        self.model = load_model(name)

    def save(self, name):
        self.model.save(name)

    pylab.figure(figsize=(18, 9))
    def PlotModel(self, score, episode):
        self.scores.append(score)
        self.episodes.append(episode)
        self.average.append(sum(self.scores) / len(self.scores))
        pylab.plot(self.episodes, self.average, 'r')
        pylab.plot(self.episodes, self.scores, 'b')
        pylab.ylabel('Score', fontsize=18)
        pylab.xlabel('Steps', fontsize=18)
        dqn = 'DQN_'
        softupdate = ''
        if self.ddqn:
            dqn = 'DDQN_'
        if self.Soft_Update:
            softupdate = '_soft'
        try:
            pylab.savefig(dqn+self.env_name+softupdate+".png")
        except OSError:
            pass

        return str(self.average[-1])[:5]
    
    def run(self):
        for e in range(self.EPISODES):
            state = self.env.reset()
            state = np.reshape(state, [1, self.state_size])
            done = False
            i = 0
            while not done:
                #self.env.render()
                action = self.act(state)
                next_state, reward, done, _ = self.env.step(action)
                next_state = np.reshape(next_state, [1, self.state_size])
                if not done or i == self.env._max_episode_steps-1:
                    reward = reward
                else:
                    reward = -100
                self.remember(state, action, reward, next_state, done)
                state = next_state
                i += 1
                if done:
                    # every step update target model
                    self.update_target_model()
                    
                    # every episode, plot the result
                    average = self.PlotModel(i, e)
                     
                    print("episode: {}/{}, score: {}, e: {:.2}, average: {}".format(e, self.EPISODES, i, self.epsilon, average))
                    if i == self.env._max_episode_steps:
#                         print("Saving trained model as cartpole-ddqn.h5")
                        print("Saving trained model as cartpole-dqn.h5")
                        self.save("cartpole-dqn.h5")
                        break
                self.replay()

    def test(self):
#         self.load("cartpole-ddqn.h5")
        self.load("cartpole-dqn.h5")

        for e in range(self.EPISODES):
            state = self.env.reset()
            state = np.reshape(state, [1, self.state_size])
            done = False
            i = 0
            while not done:
                self.env.render()
                action = np.argmax(self.model.predict(state))
                next_state, reward, done, _ = self.env.step(action)
                state = np.reshape(next_state, [1, self.state_size])
                i += 1
                if done:
                    print("episode: {}/{}, score: {}".format(e, self.EPISODES, i))
                    break

if __name__ == "__main__":
    env_name = 'CartPole-v1'
    agent = DQNAgent(env_name)
    agent.run()
    #agent.test()
# Out:
# -------------DQN------------
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 4)]               0
#
#  dense_10 (Dense)            (None, 512)               2560
#
#  dense_11 (Dense)            (None, 256)               131328
#
#  dense_12 (Dense)            (None, 64)                16448
#
#  dense_13 (Dense)            (None, 32)                2080
#
#  dense_14 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 152,482
# Trainable params: 152,482
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 4)]               0
#
#  dense_15 (Dense)            (None, 512)               2560
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dense_17 (Dense)            (None, 64)                16448
#
#  dense_18 (Dense)            (None, 32)                2080
#
#  dense_19 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 152,482
# Trainable params: 152,482
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0/100, score: 15, e: 1.0, average: 15.0
# episode: 1/100, score: 24, e: 1.0, average: 19.5
# episode: 2/100, score: 20, e: 1.0, average: 19.66
# episode: 3/100, score: 31, e: 1.0, average: 22.5
# episode: 4/100, score: 13, e: 1.0, average: 20.6
# episode: 5/100, score: 15, e: 1.0, average: 19.66
# episode: 6/100, score: 13, e: 1.0, average: 18.71
# episode: 7/100, score: 19, e: 1.0, average: 18.75
# episode: 8/100, score: 14, e: 1.0, average: 18.22
# episode: 9/100, score: 20, e: 1.0, average: 18.4
# episode: 10/100, score: 22, e: 1.0, average: 18.72
# episode: 11/100, score: 67, e: 1.0, average: 22.75
# episode: 12/100, score: 26, e: 1.0, average: 23.0
# episode: 13/100, score: 21, e: 1.0, average: 22.85
# episode: 14/100, score: 15, e: 1.0, average: 22.33
# episode: 15/100, score: 28, e: 1.0, average: 22.68
# episode: 16/100, score: 26, e: 1.0, average: 22.88
# episode: 17/100, score: 25, e: 1.0, average: 23.0
# episode: 18/100, score: 31, e: 1.0, average: 23.42
# episode: 19/100, score: 11, e: 1.0, average: 22.8
# episode: 20/100, score: 22, e: 1.0, average: 22.76
# episode: 21/100, score: 36, e: 1.0, average: 23.36
# episode: 22/100, score: 10, e: 1.0, average: 22.78
# episode: 23/100, score: 11, e: 1.0, average: 22.29
# episode: 24/100, score: 17, e: 1.0, average: 22.08
# episode: 25/100, score: 9, e: 1.0, average: 21.57
# episode: 26/100, score: 29, e: 1.0, average: 21.85
# episode: 27/100, score: 16, e: 1.0, average: 21.64
# episode: 28/100, score: 13, e: 1.0, average: 21.34
# episode: 29/100, score: 17, e: 1.0, average: 21.2
# episode: 30/100, score: 28, e: 1.0, average: 21.41
# episode: 31/100, score: 29, e: 1.0, average: 21.65
# episode: 32/100, score: 24, e: 1.0, average: 21.72
# episode: 33/100, score: 11, e: 1.0, average: 21.41
# episode: 34/100, score: 15, e: 1.0, average: 21.22
# episode: 35/100, score: 19, e: 1.0, average: 21.16
# episode: 36/100, score: 9, e: 1.0, average: 20.83
# episode: 37/100, score: 19, e: 1.0, average: 20.78
# episode: 38/100, score: 10, e: 1.0, average: 20.51
# episode: 39/100, score: 9, e: 1.0, average: 20.22
# episode: 40/100, score: 43, e: 1.0, average: 20.78
# episode: 41/100, score: 15, e: 1.0, average: 20.64
# episode: 42/100, score: 15, e: 1.0, average: 20.51
# episode: 43/100, score: 20, e: 1.0, average: 20.5
# episode: 44/100, score: 14, e: 0.98, average: 20.35
# episode: 45/100, score: 13, e: 0.97, average: 20.19
# episode: 46/100, score: 22, e: 0.95, average: 20.23
# episode: 47/100, score: 31, e: 0.92, average: 20.45
# episode: 48/100, score: 15, e: 0.91, average: 20.34
# episode: 49/100, score: 17, e: 0.89, average: 20.28
# episode: 50/100, score: 10, e: 0.88, average: 20.07
# episode: 51/100, score: 24, e: 0.86, average: 20.15
# episode: 52/100, score: 21, e: 0.84, average: 20.16
# episode: 53/100, score: 49, e: 0.8, average: 20.70
# episode: 54/100, score: 25, e: 0.78, average: 20.78
# episode: 55/100, score: 24, e: 0.77, average: 20.83
# episode: 56/100, score: 33, e: 0.74, average: 21.05
# episode: 57/100, score: 79, e: 0.68, average: 22.05
# episode: 58/100, score: 21, e: 0.67, average: 22.03
# episode: 59/100, score: 13, e: 0.66, average: 21.88
# episode: 60/100, score: 30, e: 0.64, average: 22.01
# episode: 61/100, score: 171, e: 0.54, average: 24.41
# episode: 62/100, score: 59, e: 0.51, average: 24.96
# episode: 63/100, score: 65, e: 0.48, average: 25.59
# episode: 64/100, score: 329, e: 0.34, average: 30.26
# episode: 65/100, score: 293, e: 0.26, average: 34.24
# episode: 66/100, score: 181, e: 0.21, average: 36.43
# episode: 67/100, score: 163, e: 0.18, average: 38.29
# episode: 68/100, score: 159, e: 0.16, average: 40.04
# episode: 69/100, score: 289, e: 0.12, average: 43.6
# episode: 70/100, score: 168, e: 0.098, average: 45.35
# episode: 71/100, score: 145, e: 0.085, average: 46.73
# episode: 72/100, score: 165, e: 0.072, average: 48.35
# episode: 73/100, score: 180, e: 0.06, average: 50.13
# episode: 74/100, score: 172, e: 0.051, average: 51.76
# episode: 75/100, score: 268, e: 0.039, average: 54.60
# episode: 76/100, score: 201, e: 0.032, average: 56.50
# episode: 77/100, score: 10, e: 0.031, average: 55.91
# episode: 78/100, score: 10, e: 0.031, average: 55.32
# episode: 79/100, score: 10, e: 0.031, average: 54.76
# episode: 80/100, score: 9, e: 0.03, average: 54.19
# episode: 81/100, score: 10, e: 0.03, average: 53.65
# episode: 82/100, score: 10, e: 0.03, average: 53.13
# episode: 83/100, score: 10, e: 0.03, average: 52.61
# episode: 84/100, score: 10, e: 0.029, average: 52.11
# episode: 85/100, score: 9, e: 0.029, average: 51.61
# episode: 86/100, score: 11, e: 0.029, average: 51.14
# episode: 87/100, score: 21, e: 0.028, average: 50.80
# episode: 88/100, score: 21, e: 0.027, average: 50.47
# episode: 89/100, score: 21, e: 0.027, average: 50.14
# episode: 90/100, score: 22, e: 0.026, average: 49.83
# episode: 91/100, score: 400, e: 0.018, average: 53.64
# Saving trained model as cartpole-dqn.h5
# episode: 92/100, score: 208, e: 0.014, average: 55.30
# episode: 93/100, score: 224, e: 0.011, average: 57.09
# episode: 94/100, score: 218, e: 0.01, average: 58.78
# episode: 95/100, score: 224, e: 0.01, average: 60.51
# episode: 96/100, score: 261, e: 0.01, average: 62.57
# episode: 97/100, score: 400, e: 0.01, average: 66.02
# Saving trained model as cartpole-dqn.h5
# episode: 98/100, score: 398, e: 0.01, average: 69.37
# episode: 99/100, score: 226, e: 0.01, average: 70.94

# %% [markdown]
# # Testing for DQN Model that was traind on  1000
# and we can test with new model as well

# %%
if __name__ == "__main__":
    env_name = 'CartPole-v1'
    agent = DQNAgent(env_name)
#     agent.run()
    agent.test()
# Out:
# -------------DQN------------
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 4)]               0
#
#  dense_20 (Dense)            (None, 512)               2560
#
#  dense_21 (Dense)            (None, 256)               131328
#
#  dense_22 (Dense)            (None, 64)                16448
#
#  dense_23 (Dense)            (None, 32)                2080
#
#  dense_24 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 152,482
# Trainable params: 152,482
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 4)]               0
#
#  dense_25 (Dense)            (None, 512)               2560
#
#  dense_26 (Dense)            (None, 256)               131328
#
#  dense_27 (Dense)            (None, 64)                16448
#
#  dense_28 (Dense)            (None, 32)                2080
#
#  dense_29 (Dense)            (None, 2)                 66
#
# =================================================================
# Total params: 152,482
# Trainable params: 152,482
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0/100, score: 350
# episode: 1/100, score: 307
# episode: 2/100, score: 256
# episode: 3/100, score: 276
# episode: 4/100, score: 288
# episode: 5/100, score: 314
# episode: 6/100, score: 256
# episode: 7/100, score: 262
# episode: 8/100, score: 397
# episode: 9/100, score: 253
# episode: 10/100, score: 288
# episode: 11/100, score: 375
# episode: 12/100, score: 361
# episode: 13/100, score: 327
# episode: 14/100, score: 245
# episode: 15/100, score: 206
# episode: 16/100, score: 400
# episode: 17/100, score: 400
# episode: 18/100, score: 337
# episode: 19/100, score: 245
# episode: 20/100, score: 276
# episode: 21/100, score: 338
# episode: 22/100, score: 267
# episode: 23/100, score: 276
# episode: 24/100, score: 309
# episode: 25/100, score: 278
# episode: 26/100, score: 400
# episode: 27/100, score: 400
# episode: 28/100, score: 275
# episode: 29/100, score: 268
# episode: 30/100, score: 269
# episode: 31/100, score: 287
# episode: 32/100, score: 313
# episode: 33/100, score: 291
# episode: 34/100, score: 247
# episode: 35/100, score: 264
# episode: 36/100, score: 260
# episode: 37/100, score: 237
# episode: 38/100, score: 400
# episode: 39/100, score: 266
# episode: 40/100, score: 400
# episode: 41/100, score: 301
# episode: 42/100, score: 352
# episode: 43/100, score: 282
# episode: 44/100, score: 241
# episode: 45/100, score: 340
# episode: 46/100, score: 293
# episode: 47/100, score: 400
# episode: 48/100, score: 271
# episode: 49/100, score: 271
# episode: 50/100, score: 305
# episode: 51/100, score: 258
# episode: 52/100, score: 400
# episode: 53/100, score: 213
# episode: 54/100, score: 253
# episode: 55/100, score: 362
# episode: 56/100, score: 272
# episode: 57/100, score: 272
# episode: 58/100, score: 248
# episode: 59/100, score: 373
# episode: 60/100, score: 336
# episode: 61/100, score: 269
# episode: 62/100, score: 400
# episode: 63/100, score: 316
# episode: 64/100, score: 271
# episode: 65/100, score: 265
# episode: 66/100, score: 301
# episode: 67/100, score: 294
# episode: 68/100, score: 270
# episode: 69/100, score: 247
# episode: 70/100, score: 256
# episode: 71/100, score: 274
# episode: 72/100, score: 338
# episode: 73/100, score: 297
# episode: 74/100, score: 349
# episode: 75/100, score: 400
# episode: 76/100, score: 334
# episode: 77/100, score: 281
# episode: 78/100, score: 276
# episode: 79/100, score: 314
# episode: 80/100, score: 267
# episode: 81/100, score: 329
# episode: 82/100, score: 276
# episode: 83/100, score: 363
# episode: 84/100, score: 299
# episode: 85/100, score: 388
# episode: 86/100, score: 340
# episode: 87/100, score: 321
# episode: 88/100, score: 251
# episode: 89/100, score: 335
# episode: 90/100, score: 274
# episode: 91/100, score: 338
# episode: 92/100, score: 292
# episode: 93/100, score: 370
# episode: 94/100, score: 400
# episode: 95/100, score: 300
# episode: 96/100, score: 328
# episode: 97/100, score: 249
# episode: 98/100, score: 251
# episode: 99/100, score: 303
